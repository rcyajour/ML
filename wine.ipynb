# %%
# -*- coding: utf-8 -*-
"""
Created on Tue Aug 27 22:26:45 2024

@author: rcyajour
"""

import pandas as pd
import csv

link = "wineQT.csv"
w = pd.read_csv(link)
w
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1138                 29.0                  40.0  0.99574  3.42       0.75
# 1139                 28.0                  38.0  0.99651  3.42       0.82
# 1140                 32.0                  44.0  0.99490  3.45       0.58
# 1141                 39.0                  51.0  0.99512  3.52       0.76
# 1142                 32.0                  44.0  0.99547  3.57       0.71
#
#       alcohol  quality    Id
# 0         9.4        5     0
# 1         9.8        5     1
# 2         9.8        5     2
# 3         9.8        6     3
# 4         9.4        5     4
# ...       ...      ...   ...
# 1138     11.0        6  1592
# 1139      9.5        6  1593
# 1140     10.5        5  1594
# 1141     11.2        6  1595
# 1142     10.2        5  1597
#
# [1143 rows x 13 columns]

# %%
#storing all the column values as float.
# Stored as a list of dictionaries with each row as list containing dictionary of columns as key and data as values
wine=[]
w1=open('wineQT.csv', mode='r')
reader = csv.DictReader(w1)
for r in reader:   #r = row , k = key
    for k in r:
        r[k] = float(r[k])
       
    wine.append(r)
wine
# Out:
# [{'fixed acidity': 7.4,
#   'volatile acidity': 0.7,
#   'citric acid': 0.0,
#   'residual sugar': 1.9,
#   'chlorides': 0.076,
#   'free sulfur dioxide': 11.0,
#   'total sulfur dioxide': 34.0,
#   'density': 0.9978,
#   'pH': 3.51,
#   'sulphates': 0.56,
#   'alcohol': 9.4,
#   'quality': 5.0,
#   'Id': 0.0},
#  {'fixed acidity': 7.8,
#   'volatile acidity': 0.88,
#   'citric acid': 0.0,
#   'residual sugar': 2.6,
#   'chlorides': 0.098,
#   'free sulfur dioxide': 25.0,
#   'total sulfur dioxide': 67.0,
#   'density': 0.9968,
#   'pH': 3.2,
#   'sulphates': 0.68,
#   'alcohol': 9.8,
#   'quality': 5.0,
#   'Id': 1.0},
#  {'fixed acidity': 7.8,
#   'volatile acidity': 0.76,
#   'citric acid': 0.04,
#   'residual sugar': 2.3,
#   'chlorides': 0.092,
#   'free sulfur dioxide': 15.0,
#   'total sulfur dioxide': 54.0,
#   'density': 0.997,
#   'pH': 3.26,
#   'sulphates': 0.65,
#   'alcohol': 9.8,
#   'quality': 5.0,
#   'Id': 2.0},
#  {'fixed acidity': 11.2,
#   'volatile acidity': 0.28,
#   'citric acid': 0.56,
#   'residual sugar': 1.9,
#   'chlorides': 0.075,
#   'free sulfur dioxide': 17.0,
#   'total sulfur dioxide': 60.0,
#   'density': 0.998,
#   'pH': 3.16,
#   'sulphates': 0.58,
#   'alcohol': 9.8,
#   'quality': 6.0,
#   'Id': 3.0},
#  {'fixed acidity': 7.4,
#   'volatile acidity': 0.7,
#   'citric acid': 0.0,
#   'residual sugar': 1.9,
#   'chlorides': 0.076,
#   'free sulfur dioxide': 11.0,
#   'total sulfur dioxide': 34.0,
#   'density': 0.9978,
#   'pH': 3.51,
#   'sulphates': 0.56,
#   'alcohol': 9.4,
#   'quality': 5.0,
#   'Id': 4.0},
#  {'fixed acidity': 7.4,
#   'volatile acidity': 0.66,
#   'citric acid': 0.0,
#   'residual sugar': 1.8,
#   'chlorides': 0.075,
#   'free sulfur dioxide': 13.0,
#   'total sulfur dioxide': 40.0,
#   'density': 0.9978,
#   'pH': 3.51,
#   'sulphates': 0.56,
#   'alcohol': 9.4,
#   'quality': 5.0,
#   'Id': 5.0},
#  {'fixed acidity': 7.9,
#   'volatile acidity': 0.6,
#   'citric acid': 0.06,
#   'residual sugar': 1.6,
#   'chlorides': 0.069,
#   'free sulfur dioxide': 15.0,
#   'total sulfur dioxide': 59.0,
#   'density': 0.9964,
#   'pH': 3.3,
#   'sulphates': 0.46,
#   'alcohol': 9.4,
#   'quality': 5.0,
#   'Id': 6.0},
#  {'fixed acidity': 7.3,
#   'volatile acidity': 0.65,
#   'citric acid': 0.0,
#   'residual sugar': 1.2,
#   'chlorides': 0.065,
#   'free sulfur dioxide': 15.0,
#   'total sulfur dioxide': 21.0,
#   'density': 0.9946,
#   'pH': 3.39,
#   'sulphates': 0.47,
#   'alcohol': 10.0,
#   'quality': 7.0,
#   'Id': 7.0},
#  {'fixed acidity': 7.8,
#   'volatile acidity': 0.58,
#   'citric acid': 0.02,
#   'residual sugar': 2.0,
#   'chlorides': 0.073,
#   'free sulfur dioxide': 9.0,
#   'total sulfur dioxide': 18.0,
#   'density': 0.9968,
#   'pH': 3.36,
#   'sulphates': 0.57,
#   'alcohol': 9.5,
#   'quality': 7.0,
#   'Id': 8.0},
#  {'fixed acidity': 6.7,
#   'volatile acidity': 0.58,
#   'citric acid': 0.08,
#   'residual sugar': 1.8,
#   'chlorides': 0.09699999999999999,
#   'free sulfur dioxide': 15.0,
#   'total sulfur dioxide': 65.0,
#   'density': 0.9959,
#   'pH': 3.28,
#   'sulphates': 0.54,
#   'alcohol': 9.2,
#   'quality': 5.0,
#   'Id': 10.0},
#  {'fixed acidity': 5.6,
#   'volatile acidity': 0.615,
#   'citric acid': 0.0,
#   'residual sugar': 1.6,
#   'chlorides': 0.08900000000000001,
#   'free sulfur dioxide': 16.0,
#   'total sulfur dioxide': 59.0,
#   'density': 0.9943,
#   'pH': 3.58,
#   'sulphates': 0.52,
#   'alcohol': 9.9,
#   'quality': 5.0,
#   'Id': 12.0},
#  {'fixed acidity': 7.8,
#   'volatile acidity': 0.61,
#   'citric acid': 0.29,
#   'residual sugar': 1.6,
#   'chlorides': 0.114,
#   'free sulfur dioxide': 9.0,
#   'total sulfur dioxide': 29.0,
#   'density': 0.9974,
#   'pH': 3.26,
#   'sulphates': 1.56,
#   'alcohol': 9.1,
#   'quality': 5.0,
#   'Id': 13.0},
#  {'fixed acidity': 8.5,
#   'volatile acidity': 0.28,
#   'citric acid': 0.56,
#   'residual sugar': 1.8,
#   'chlorides': 0.092,
#   'free sulfur dioxide': 35.0,
#   'total sulfur dioxide': 103.0,
#   'density': 0.9969,
#   'pH': 3.3,
#   'sulphates': 0.75,
#   'alcohol': 10.5,
#   'quality': 7.0,
#   'Id': 16.0},
#  {'fixed acidity': 7.9,
#   'volatile acidity': 0.32,
#   'citric acid': 0.51,
#   'residual sugar': 1.8,
#   'chlorides': 0.341,
#   'free sulfur dioxide': 17.0,
#   'total sulfur dioxide': 56.0,
#   'density': 0.9969,
#   'pH': 3.04,
#   'sulphates': 1.08,
#   'alcohol': 9.2,
#   'quality': 6.0,
#   'Id': 19.0},
#  {'fixed acidity': 7.6,
#   'volatile acidity': 0.39,
#   'citric acid': 0.31,
#   'residual sugar': 2.3,
#   'chlorides': 0.08199999999999999,
#   'free sulfur dioxide': 23.0,
#   'total sulfur dioxide': 71.0,
#   'density': 0.9982,
#   'pH': 3.52,
#   'sulphates': 0.65,
#   'alcohol': 9.7,
#   'quality': 5.0,
#   'Id': 21.0},
#  {'fixed acidity': 7.9,
#   'volatile acidity': 0.43,
#   'citric acid': 0.21,
#   'residual sugar': 1.6,
#   'chlorides': 0.106,
#   'free sulfur dioxide': 10.0,
#   'total sulfur dioxide': 37.0,
#   'density': 0.9966,
#   'pH': 3.17,
#   'sulphates': 0.91,
#   'alcohol': 9.5,
#   'quality': 5.0,
#   'Id': 22.0},
#  {'fixed acidity': 8.5,
#   'volatile acidity': 0.49,
#   'citric acid': 0.11,
#   'residual sugar': 2.3,
#   'chlorides': 0.084,
#   'free sulfur dioxide': 9.0,
#   'total sulfur dioxide': 67.0,
#   'density': 0.9968,
#   'pH': 3.17,
#   'sulphates': 0.53,
#   'alcohol': 9.4,
#   'quality': 5.0,
#   'Id': 23.0},
#  {'fixed acidity': 6.9,
#   'volatile acidity': 0.4,
#   'citric acid': 0.14,
#   'residual sugar': 2.4,
#   'chlorides': 0.085,
#   'free sulfur dioxide': 21.0,
#   'total sulfur dioxide': 40.0,
#   'density': 0.9968,
#   'pH': 3.43,
#   'sulphates': 0.63,
#   'alcohol': 9.7,
#   'quality': 6.0,
#   'Id': 24.0},
#  {'fixed acidity': 6.3,
#   'volatile acidity': 0.39,
#   'citric acid': 0.16,
#   'residual sugar': 1.4,
#   'chlorides': 0.08,
#   'free sulfur dioxide': 11.0,
#   'total sulfur dioxide': 23.0,
#   'density': 0.9955,
#   'pH': 3.34,
#   'sulphates': 0.56,
#   'alcohol': 9.3,
#   'quality': 5.0,
#   'Id': 25.0},
#  {'fixed acidity': 7.6,
#   'volatile acidity': 0.41,
#   'citric acid': 0.24,
#   'residual sugar': 1.8,
#   'chlorides': 0.08,
#   'free sulfur dioxide': 4.0,
#   'total sulfur dioxide': 11.0,
#   'density': 0.9962,
#   'pH': 3.28,
#   'sulphates': 0.59,
#   'alcohol': 9.5,
#   'quality': 5.0,
#   'Id': 26.0},
#  {'fixed acidity': 7.1,
#   'volatile acidity': 0.71,
#   'citric acid': 0.0,
#   'residual sugar': 1.9,
#   'chlorides': 0.08,
#   'free sulfur dioxide': 14.0,
#   'total sulfur dioxide': 35.0,
#   'density': 0.9972,
#   'pH': 3.47,
#   'sulphates': 0.55,
#   'alcohol': 9.4,
#   'quality': 5.0,
#   'Id': 28.0},
#  {'fixed acidity': 7.8,
#   'volatile acidity': 0.645,
#   'citric acid': 0.0,
#   'residual sugar': 2.0,
#   'chlorides': 0.08199999999999999,
#   'free sulfur dioxide': 8.0,
#   'total sulfur dioxide': 16.0,
#   'density': 0.9964,
#   'pH': 3.38,
#   'sulphates': 0.59,
#   'alcohol': 9.8,
#   'quality': 6.0,
#   'Id': 29.0},
#  {'fixed acidity': 6.7,
#   'volatile acidity': 0.675,
#   'citric acid': 0.07,
#   'residual sugar': 2.4,
#   'chlorides': 0.08900000000000001,
#   'free sulfur dioxide': 17.0,
#   'total sulfur dioxide': 82.0,
#   'density': 0.9958,
#   'pH': 3.35,
#   'sulphates': 0.54,
#   'alcohol': 10.1,
#   'quality': 5.0,
#   'Id': 30.0},
#  {'fixed acidity': 8.3,
#   'volatile acidity': 0.655,
#   'citric acid': 0.12,
#   'residual sugar': 2.3,
#   'chlorides': 0.083,
#   'free sulfur dioxide': 15.0,
#   'total sulfur dioxide': 113.0,
#   'density': 0.9966,
#   'pH': 3.17,
#   'sulphates': 0.66,
#   'alcohol': 9.8,
#   'quality': 5.0,
#   'Id': 32.0},
#  {'fixed acidity': 5.2,
#   'volatile acidity': 0.32,
#   'citric acid': 0.25,
#   'residual sugar': 1.8,
#   'chlorides': 0.10300000000000001,
#   'free sulfur dioxide': 13.0,
#   'total sulfur dioxide': 50.0,
#   'density': 0.9957,
#   'pH': 3.38,
#   'sulphates': 0.55,
#   'alcohol': 9.2,
#   'quality': 5.0,
#   'Id': 34.0},
#  {'fixed acidity': 7.8,
#   'volatile acidity': 0.645,
#   'citric acid': 0.0,
#   'residual sugar': 5.5,
#   'chlorides': 0.086,
#   'free sulfur dioxide': 5.0,
#   'total sulfur dioxide': 18.0,
#   'density': 0.9986,
#   'pH': 3.4,
#   'sulphates': 0.55,
#   'alcohol': 9.6,
#   'quality': 6.0,
#   'Id': 35.0},
#  {'fixed acidity': 7.8,
#   'volatile acidity': 0.6,
#   'citric acid': 0.14,
#   'residual sugar': 2.4,
#   'chlorides': 0.086,
#   'free sulfur dioxide': 3.0,
#   'total sulfur dioxide': 15.0,
#   'density': 0.9975,
#   'pH': 3.42,
#   'sulphates': 0.6,
#   'alcohol': 10.8,
#   'quality': 6.0,
#   'Id': 36.0},
#  {'fixed acidity': 8.1,
#   'volatile acidity': 0.38,
#   'citric acid': 0.28,
#   'residual sugar': 2.1,
#   'chlorides': 0.066,
#   'free sulfur dioxide': 13.0,
#   'total sulfur dioxide': 30.0,
#   'density': 0.9968,
#   'pH': 3.23,
#   'sulphates': 0.73,
#   'alcohol': 9.7,
#   'quality': 7.0,
#   'Id': 37.0},
#  {'fixed acidity': 7.3,
#   'volatile acidity': 0.45,
#   'citric acid': 0.36,
#   'residual sugar': 5.9,
#   'chlorides': 0.07400000000000001,
#   'free sulfur dioxide': 12.0,
#   'total sulfur dioxide': 87.0,
#   'density': 0.9978,
#   'pH': 3.33,
#   'sulphates': 0.83,
#   'alcohol': 10.5,
#   'quality': 5.0,
#   'Id': 40.0},
#  {'fixed acidity': 8.8,
#   'volatile acidity': 0.61,
#   'citric acid': 0.3,
#   'residual sugar': 2.8,
#   'chlorides': 0.08800000000000001,
#   'free sulfur dioxide': 17.0,
#   'total sulfur dioxide': 46.0,
#   'density': 0.9976,
#   'pH': 3.26,
#   'sulphates': 0.51,
#   'alcohol': 9.3,
#   'quality': 4.0,
#   'Id': 41.0},
#  {'fixed acidity': 7.5,
#   'volatile acidity': 0.49,
#   'citric acid': 0.2,
#   'residual sugar': 2.6,
#   'chlorides': 0.332,
#   'free sulfur dioxide': 8.0,
#   'total sulfur dioxide': 14.0,
#   'density': 0.9968,
#   'pH': 3.21,
#   'sulphates': 0.9,
#   'alcohol': 10.5,
#   'quality': 6.0,
#   'Id': 42.0},
#  {'fixed acidity': 8.1,
#   'volatile acidity': 0.66,
#   'citric acid': 0.22,
#   'residual sugar': 2.2,
#   'chlorides': 0.069,
#   'free sulfur dioxide': 9.0,
#   'total sulfur dioxide': 23.0,
#   'density': 0.9968,
#   'pH': 3.3,
#   'sulphates': 1.2,
#   'alcohol': 10.3,
#   'quality': 5.0,
#   'Id': 43.0},
#  {'fixed acidity': 4.6,
#   'volatile acidity': 0.52,
#   'citric acid': 0.15,
#   'residual sugar': 2.1,
#   'chlorides': 0.054000000000000006,
#   'free sulfur dioxide': 8.0,
#   'total sulfur dioxide': 65.0,
#   'density': 0.9934,
#   'pH': 3.9,
#   'sulphates': 0.56,
#   'alcohol': 13.1,
#   'quality': 4.0,
#   'Id': 45.0},
#  {'fixed acidity': 7.7,
#   'volatile acidity': 0.935,
#   'citric acid': 0.43,
#   'residual sugar': 2.2,
#   'chlorides': 0.114,
#   'free sulfur dioxide': 22.0,
#   'total sulfur dioxide': 114.0,
#   'density': 0.997,
#   'pH': 3.25,
#   'sulphates': 0.73,
#   'alcohol': 9.2,
#   'quality': 5.0,
#   'Id': 46.0},
#  {'fixed acidity': 8.8,
#   'volatile acidity': 0.66,
#   'citric acid': 0.26,
#   'residual sugar': 1.7,
#   'chlorides': 0.07400000000000001,
#   'free sulfur dioxide': 4.0,
#   'total sulfur dioxide': 23.0,
#   'density': 0.9971,
#   'pH': 3.15,
#   'sulphates': 0.74,
#   'alcohol': 9.2,
#   'quality': 5.0,
#   'Id': 50.0},
#  {'fixed acidity': 6.6,
#   'volatile acidity': 0.52,
#   'citric acid': 0.04,
#   'residual sugar': 2.2,
#   'chlorides': 0.069,
#   'free sulfur dioxide': 8.0,
#   'total sulfur dioxide': 15.0,
#   'density': 0.9956,
#   'pH': 3.4,
#   'sulphates': 0.63,
#   'alcohol': 9.4,
#   'quality': 6.0,
#   'Id': 51.0},
#  {'fixed acidity': 6.6,
#   'volatile acidity': 0.5,
#   'citric acid': 0.04,
#   'residual sugar': 2.1,
#   'chlorides': 0.068,
#   'free sulfur dioxide': 6.0,
#   'total sulfur dioxide': 14.0,
#   'density': 0.9955,
#   'pH': 3.39,
#   'sulphates': 0.64,
#   'alcohol': 9.4,
#   'quality': 6.0,
#   'Id': 52.0},
#  {'fixed acidity': 8.6,
#   'volatile acidity': 0.38,
#   'citric acid': 0.36,
#   'residual sugar': 3.0,
#   'chlorides': 0.081,
#   'free sulfur dioxide': 30.0,
#   'total sulfur dioxide': 119.0,
#   'density': 0.997,
#   'pH': 3.2,
#   'sulphates': 0.56,
#   'alcohol': 9.4,
#   'quality': 5.0,
#   'Id': 53.0},
#  {'fixed acidity': 7.6,
#   'volatile acidity': 0.51,
#   'citric acid': 0.15,
#   'residual sugar': 2.8,
#   'chlorides': 0.11,
#   'free sulfur dioxide': 33.0,
#   'total sulfur dioxide': 73.0,
#   'density': 0.9955,
#   'pH': 3.17,
#   'sulphates': 0.63,
#   'alcohol': 10.2,
#   'quality': 6.0,
#   'Id': 54.0},
#  {'fixed acidity': 10.2,
#   'volatile acidity': 0.42,
#   'citric acid': 0.57,
#   'residual sugar': 3.4,
#   'chlorides': 0.07,
#   'free sulfur dioxide': 4.0,
#   'total sulfur dioxide': 10.0,
#   'density': 0.9971,
#   'pH': 3.04,
#   'sulphates': 0.63,
#   'alcohol': 9.6,
#   'quality': 5.0,
#   'Id': 56.0},
#  {'fixed acidity': 7.8,
#   'volatile acidity': 0.59,
#   'citric acid': 0.18,
#   'residual sugar': 2.3,
#   'chlorides': 0.076,
#   'free sulfur dioxide': 17.0,
#   'total sulfur dioxide': 54.0,
#   'density': 0.9975,
#   'pH': 3.43,
#   'sulphates': 0.59,
#   'alcohol': 10.0,
#   'quality': 5.0,
#   'Id': 58.0},
#  {'fixed acidity': 7.3,
#   'volatile acidity': 0.39,
#   'citric acid': 0.31,
#   'residual sugar': 2.4,
#   'chlorides': 0.07400000000000001,
#   'free sulfur dioxide': 9.0,
#   'total sulfur dioxide': 46.0,
#   'density': 0.9962,
#   'pH': 3.41,
#   'sulphates': 0.54,
#   'alcohol': 9.4,
#   'quality': 6.0,
#   'Id': 59.0},
#  {'fixed acidity': 8.8,
#   'volatile acidity': 0.4,
#   'citric acid': 0.4,
#   'residual sugar': 2.2,
#   'chlorides': 0.079,
#   'free sulfur dioxide': 19.0,
#   'total sulfur dioxide': 52.0,
#   'density': 0.998,
#   'pH': 3.44,
#   'sulphates': 0.64,
#   'alcohol': 9.2,
#   'quality': 5.0,
#   'Id': 60.0},
#  {'fixed acidity': 7.7,
#   'volatile acidity': 0.69,
#   'citric acid': 0.49,
#   'residual sugar': 1.8,
#   'chlorides': 0.115,
#   'free sulfur dioxide': 20.0,
#   'total sulfur dioxide': 112.0,
#   'density': 0.9968,
#   'pH': 3.21,
#   'sulphates': 0.71,
#   'alcohol': 9.3,
#   'quality': 5.0,
#   'Id': 61.0},
#  {'fixed acidity': 7.0,
#   'volatile acidity': 0.735,
#   'citric acid': 0.05,
#   'residual sugar': 2.0,
#   'chlorides': 0.081,
#   'free sulfur dioxide': 13.0,
#   'total sulfur dioxide': 54.0,
#   'density': 0.9966,
#   'pH': 3.39,
#   'sulphates': 0.57,
#   'alcohol': 9.8,
#   'quality': 5.0,
#   'Id': 63.0},
#  {'fixed acidity': 7.2,
#   'volatile acidity': 0.725,
#   'citric acid': 0.05,
#   'residual sugar': 4.65,
#   'chlorides': 0.086,
#   'free sulfur dioxide': 4.0,
#   'total sulfur dioxide': 11.0,
#   'density': 0.9962,
#   'pH': 3.41,
#   'sulphates': 0.39,
#   'alcohol': 10.9,
#   'quality': 5.0,
#   'Id': 64.0},
#  {'fixed acidity': 7.2,
#   'volatile acidity': 0.725,
#   'citric acid': 0.05,
#   'residual sugar': 4.65,
#   'chlorides': 0.086,
#   'free sulfur dioxide': 4.0,
#   'total sulfur dioxide': 11.0,
#   'density': 0.9962,
#   'pH': 3.41,
#   'sulphates': 0.39,
#   'alcohol': 10.9,
#   'quality': 5.0,
#   'Id': 65.0},
#  {'fixed acidity': 6.6,
#   'volatile acidity': 0.705,
#   'citric acid': 0.07,
#   'residual sugar': 1.6,
#   'chlorides': 0.076,
#   'free sulfur dioxide': 6.0,
#   'total sulfur dioxide': 15.0,
#   'density': 0.9962,
#   'pH': 3.44,
#   'sulphates': 0.58,
#   'alcohol': 10.7,
#   'quality': 5.0,
#   'Id': 67.0},
#  {'fixed acidity': 8.0,
#   'volatile acidity': 0.705,
#   'citric acid': 0.05,
#   'residual sugar': 1.9,
#   'chlorides': 0.07400000000000001,
#   'free sulfur dioxide': 8.0,
#   'total sulfur dioxide': 19.0,
#   'density': 0.9962,
#   'pH': 3.34,
#   'sulphates': 0.95,
#   'alcohol': 10.5,
#   'quality': 6.0,
#   'Id': 69.0},
#  {'fixed acidity': 7.7,
#   'volatile acidity': 0.69,
#   'citric acid': 0.22,
#   'residual sugar': 1.9,
#   'chlorides': 0.084,
#   'free sulfur dioxide': 18.0,
#   'total sulfur dioxide': 94.0,
#   'density': 0.9961,
#   'pH': 3.31,
#   'sulphates': 0.48,
#   'alcohol': 9.5,
#   'quality': 5.0,
#   'Id': 72.0},
#  {'fixed acidity': 8.3,
#   'volatile acidity': 0.675,
#   'citric acid': 0.26,
#   'residual sugar': 2.1,
#   'chlorides': 0.084,
#   'free sulfur dioxide': 11.0,
#   'total sulfur dioxide': 43.0,
#   'density': 0.9976,
#   'pH': 3.31,
#   'sulphates': 0.53,
#   'alcohol': 9.2,
#   'quality': 4.0,
#   'Id': 73.0},
#  {'fixed acidity': 8.8,
#   'volatile acidity': 0.41,
#   'citric acid': 0.64,
#   'residual sugar': 2.2,
#   'chlorides': 0.09300000000000001,
#   'free sulfur dioxide': 9.0,
#   'total sulfur dioxide': 42.0,
#   'density': 0.9986,
#   'pH': 3.54,
#   'sulphates': 0.66,
#   'alcohol': 10.5,
#   'quality': 5.0,
#   'Id': 76.0},
#  {'fixed acidity': 6.8,
#   'volatile acidity': 0.785,
#   'citric acid': 0.0,
#   'residual sugar': 2.4,
#   'chlorides': 0.10400000000000001,
#   'free sulfur dioxide': 14.0,
#   'total sulfur dioxide': 30.0,
#   'density': 0.9966,
#   'pH': 3.52,
#   'sulphates': 0.55,
#   'alcohol': 10.7,
#   'quality': 6.0,
#   'Id': 77.0},
#  {'fixed acidity': 6.7,
#   'volatile acidity': 0.75,
#   'citric acid': 0.12,
#   'residual sugar': 2.0,
#   'chlorides': 0.086,
#   'free sulfur dioxide': 12.0,
#   'total sulfur dioxide': 80.0,
#   'density': 0.9958,
#   'pH': 3.38,
#   'sulphates': 0.52,
#   'alcohol': 10.1,
#   'quality': 5.0,
#   'Id': 78.0},
#  {'fixed acidity': 8.3,
#   'volatile acidity': 0.625,
#   'citric acid': 0.2,
#   'residual sugar': 1.5,
#   'chlorides': 0.08,
#   'free sulfur dioxide': 27.0,
#   'total sulfur dioxide': 119.0,
#   'density': 0.9972,
#   'pH': 3.16,
#   'sulphates': 1.12,
#   'alcohol': 9.1,
#   'quality': 4.0,
#   'Id': 79.0},
#  {'fixed acidity': 6.2,
#   'volatile acidity': 0.45,
#   'citric acid': 0.2,
#   'residual sugar': 1.6,
#   'chlorides': 0.069,
#   'free sulfur dioxide': 3.0,
#   'total sulfur dioxide': 15.0,
#   'density': 0.9958,
#   'pH': 3.41,
#   'sulphates': 0.56,
#   'alcohol': 9.2,
#   'quality': 5.0,
#   'Id': 80.0},
#  {'fixed acidity': 7.4,
#   'volatile acidity': 0.5,
#   'citric acid': 0.47,
#   'residual sugar': 2.0,
#   'chlorides': 0.086,
#   'free sulfur dioxide': 21.0,
#   'total sulfur dioxide': 73.0,
#   'density': 0.997,
#   'pH': 3.36,
#   'sulphates': 0.57,
#   'alcohol': 9.1,
#   'quality': 5.0,
#   'Id': 82.0},
#  {'fixed acidity': 6.3,
#   'volatile acidity': 0.3,
#   'citric acid': 0.48,
#   'residual sugar': 1.8,
#   'chlorides': 0.069,
#   'free sulfur dioxide': 18.0,
#   'total sulfur dioxide': 61.0,
#   'density': 0.9959,
#   'pH': 3.44,
#   'sulphates': 0.78,
#   'alcohol': 10.3,
#   'quality': 6.0,
#   'Id': 84.0},
#  {'fixed acidity': 6.9,
#   'volatile acidity': 0.55,
#   'citric acid': 0.15,
#   'residual sugar': 2.2,
#   'chlorides': 0.076,
#   'free sulfur dioxide': 19.0,
#   'total sulfur dioxide': 40.0,
#   'density': 0.9961,
#   'pH': 3.41,
#   'sulphates': 0.59,
#   'alcohol': 10.1,
#   'quality': 5.0,
#   'Id': 85.0},
#  {'fixed acidity': 8.6,
#   'volatile acidity': 0.49,
#   'citric acid': 0.28,
#   'residual sugar': 1.9,
#   'chlorides': 0.11,
#   'free sulfur dioxide': 20.0,
#   'total sulfur dioxide': 136.0,
#   'density': 0.9972,
#   'pH': 2.93,
#   'sulphates': 1.95,
#   'alcohol': 9.9,
#   'quality': 6.0,
#   'Id': 86.0},
#  {'fixed acidity': 7.7,
#   'volatile acidity': 0.49,
#   'citric acid': 0.26,
#   'residual sugar': 1.9,
#   'chlorides': 0.062,
#   'free sulfur dioxide': 9.0,
#   'total sulfur dioxide': 31.0,
#   'density': 0.9966,
#   'pH': 3.39,
#   'sulphates': 0.64,
#   'alcohol': 9.6,
#   'quality': 5.0,
#   'Id': 87.0},
#  {'fixed acidity': 9.3,
#   'volatile acidity': 0.39,
#   'citric acid': 0.44,
#   'residual sugar': 2.1,
#   'chlorides': 0.107,
#   'free sulfur dioxide': 34.0,
#   'total sulfur dioxide': 125.0,
#   'density': 0.9978,
#   'pH': 3.14,
#   'sulphates': 1.22,
#   'alcohol': 9.5,
#   'quality': 5.0,
#   'Id': 88.0},
#  {'fixed acidity': 7.0,
#   'volatile acidity': 0.62,
#   'citric acid': 0.08,
#   'residual sugar': 1.8,
#   'chlorides': 0.076,
#   'free sulfur dioxide': 8.0,
#   'total sulfur dioxide': 24.0,
#   'density': 0.9978,
#   'pH': 3.48,
#   'sulphates': 0.53,
#   'alcohol': 9.0,
#   'quality': 5.0,
#   'Id': 89.0},
#  {'fixed acidity': 7.9,
#   'volatile acidity': 0.52,
#   'citric acid': 0.26,
#   'residual sugar': 1.9,
#   'chlorides': 0.079,
#   'free sulfur dioxide': 42.0,
#   'total sulfur dioxide': 140.0,
#   'density': 0.9964,
#   'pH': 3.23,
#   'sulphates': 0.54,
#   'alcohol': 9.5,
#   'quality': 5.0,
#   'Id': 90.0},
#  {'fixed acidity': 8.6,
#   'volatile acidity': 0.49,
#   'citric acid': 0.28,
#   'residual sugar': 1.9,
#   'chlorides': 0.11,
#   'free sulfur dioxide': 20.0,
#   'total sulfur dioxide': 136.0,
#   'density': 0.9972,
#   'pH': 2.93,
#   'sulphates': 1.95,
#   'alcohol': 9.9,
#   'quality': 6.0,
#   'Id': 91.0},
#  {'fixed acidity': 7.7,
#   'volatile acidity': 0.49,
#   'citric acid': 0.26,
#   'residual sugar': 1.9,
#   'chlorides': 0.062,
#   'free sulfur dioxide': 9.0,
#   'total sulfur dioxide': 31.0,
#   'density': 0.9966,
#   'pH': 3.39,
#   'sulphates': 0.64,
#   'alcohol': 9.6,
#   'quality': 5.0,
#   'Id': 93.0},
#  {'fixed acidity': 5.0,
#   'volatile acidity': 1.02,
#   'citric acid': 0.04,
#   'residual sugar': 1.4,
#   'chlorides': 0.045,
#   'free sulfur dioxide': 41.0,
#   'total sulfur dioxide': 85.0,
#   'density': 0.9938,
#   'pH': 3.75,
#   'sulphates': 0.48,
#   'alcohol': 10.5,
#   'quality': 4.0,
#   'Id': 94.0},
#  {'fixed acidity': 6.8,
#   'volatile acidity': 0.775,
#   'citric acid': 0.0,
#   'residual sugar': 3.0,
#   'chlorides': 0.102,
#   'free sulfur dioxide': 8.0,
#   'total sulfur dioxide': 23.0,
#   'density': 0.9965,
#   'pH': 3.45,
#   'sulphates': 0.56,
#   'alcohol': 10.7,
#   'quality': 5.0,
#   'Id': 96.0},
#  {'fixed acidity': 7.6,
#   'volatile acidity': 0.9,
#   'citric acid': 0.06,
#   'residual sugar': 2.5,
#   'chlorides': 0.079,
#   'free sulfur dioxide': 5.0,
#   'total sulfur dioxide': 10.0,
#   'density': 0.9967,
#   'pH': 3.39,
#   'sulphates': 0.56,
#   'alcohol': 9.8,
#   'quality': 5.0,
#   'Id': 98.0},
#  {'fixed acidity': 8.1,
#   'volatile acidity': 0.545,
#   'citric acid': 0.18,
#   'residual sugar': 1.9,
#   'chlorides': 0.08,
#   'free sulfur dioxide': 13.0,
#   'total sulfur dioxide': 35.0,
#   'density': 0.9972,
#   'pH': 3.3,
#   'sulphates': 0.59,
#   'alcohol': 9.0,
#   'quality': 6.0,
#   'Id': 99.0},
#  {'fixed acidity': 8.3,
#   'volatile acidity': 0.61,
#   'citric acid': 0.3,
#   'residual sugar': 2.1,
#   'chlorides': 0.084,
#   'free sulfur dioxide': 11.0,
#   'total sulfur dioxide': 50.0,
#   'density': 0.9972,
#   'pH': 3.4,
#   'sulphates': 0.61,
#   'alcohol': 10.2,
#   'quality': 6.0,
#   'Id': 100.0},
#  {'fixed acidity': 8.1,
#   'volatile acidity': 0.545,
#   'citric acid': 0.18,
#   'residual sugar': 1.9,
#   'chlorides': 0.08,
#   'free sulfur dioxide': 13.0,
#   'total sulfur dioxide': 35.0,
#   'density': 0.9972,
#   'pH': 3.3,
#   'sulphates': 0.59,
#   'alcohol': 9.0,
#   'quality': 6.0,
#   'Id': 102.0},
#  {'fixed acidity': 8.1,
#   'volatile acidity': 0.575,
#   'citric acid': 0.22,
#   'residual sugar': 2.1,
#   'chlorides': 0.077,
#   'free sulfur dioxide': 12.0,
#   'total sulfur dioxide': 65.0,
#   'density': 0.9967,
#   'pH': 3.29,
#   'sulphates': 0.51,
#   'alcohol': 9.2,
#   'quality': 5.0,
#   'Id': 103.0},
#  {'fixed acidity': 7.2,
#   'volatile acidity': 0.49,
#   'citric acid': 0.24,
#   'residual sugar': 2.2,
#   'chlorides': 0.07,
#   'free sulfur dioxide': 5.0,
#   'total sulfur dioxide': 36.0,
#   'density': 0.996,
#   'pH': 3.33,
#   'sulphates': 0.48,
#   'alcohol': 9.4,
#   'quality': 5.0,
#   'Id': 104.0},
#  {'fixed acidity': 8.1,
#   'volatile acidity': 0.575,
#   'citric acid': 0.22,
#   'residual sugar': 2.1,
#   'chlorides': 0.077,
#   'free sulfur dioxide': 12.0,
#   'total sulfur dioxide': 65.0,
#   'density': 0.9967,
#   'pH': 3.29,
#   'sulphates': 0.51,
#   'alcohol': 9.2,
#   'quality': 5.0,
#   'Id': 105.0},
#  {'fixed acidity': 7.8,
#   'volatile acidity': 0.41,
#   'citric acid': 0.68,
#   'residual sugar': 1.7,
#   'chlorides': 0.467,
#   'free sulfur dioxide': 18.0,
#   'total sulfur dioxide': 69.0,
#   'density': 0.9973,
#   'pH': 3.08,
#   'sulphates': 1.31,
#   'alcohol': 9.3,
#   'quality': 5.0,
#   'Id': 106.0},
#  {'fixed acidity': 6.2,
#   'volatile acidity': 0.63,
#   'citric acid': 0.31,
#   'residual sugar': 1.7,
#   'chlorides': 0.08800000000000001,
#   'free sulfur dioxide': 15.0,
#   'total sulfur dioxide': 64.0,
#   'density': 0.9969,
#   'pH': 3.46,
#   'sulphates': 0.79,
#   'alcohol': 9.3,
#   'quality': 5.0,
#   'Id': 107.0},
#  {'fixed acidity': 7.8,
#   'volatile acidity': 0.56,
#   'citric acid': 0.19,
#   'residual sugar': 1.8,
#   'chlorides': 0.10400000000000001,
#   'free sulfur dioxide': 12.0,
#   'total sulfur dioxide': 47.0,
#   'density': 0.9964,
#   'pH': 3.19,
#   'sulphates': 0.93,
#   'alcohol': 9.5,
#   'quality': 5.0,
#   'Id': 110.0},
#  {'fixed acidity': 8.4,
#   'volatile acidity': 0.62,
#   'citric acid': 0.09,
#   'residual sugar': 2.2,
#   'chlorides': 0.084,
#   'free sulfur dioxide': 11.0,
#   'total sulfur dioxide': 108.0,
#   'density': 0.9964,
#   'pH': 3.15,
#   'sulphates': 0.66,
#   'alcohol': 9.8,
#   'quality': 5.0,
#   'Id': 111.0},
#  {'fixed acidity': 10.1,
#   'volatile acidity': 0.31,
#   'citric acid': 0.44,
#   'residual sugar': 2.3,
#   'chlorides': 0.08,
#   'free sulfur dioxide': 22.0,
#   'total sulfur dioxide': 46.0,
#   'density': 0.9988,
#   'pH': 3.32,
#   'sulphates': 0.67,
#   'alcohol': 9.7,
#   'quality': 6.0,
#   'Id': 113.0},
#  {'fixed acidity': 7.8,
#   'volatile acidity': 0.56,
#   'citric acid': 0.19,
#   'residual sugar': 1.8,
#   'chlorides': 0.10400000000000001,
#   'free sulfur dioxide': 12.0,
#   'total sulfur dioxide': 47.0,
#   'density': 0.9964,
#   'pH': 3.19,
#   'sulphates': 0.93,
#   'alcohol': 9.5,
#   'quality': 5.0,
#   'Id': 114.0},
#  {'fixed acidity': 9.4,
#   'volatile acidity': 0.4,
#   'citric acid': 0.31,
#   'residual sugar': 2.2,
#   'chlorides': 0.09,
#   'free sulfur dioxide': 13.0,
#   'total sulfur dioxide': 62.0,
#   'density': 0.9966,
#   'pH': 3.07,
#   'sulphates': 0.63,
#   'alcohol': 10.5,
#   'quality': 6.0,
#   'Id': 115.0},
#  {'fixed acidity': 8.3,
#   'volatile acidity': 0.54,
#   'citric acid': 0.28,
#   'residual sugar': 1.9,
#   'chlorides': 0.077,
#   'free sulfur dioxide': 11.0,
#   'total sulfur dioxide': 40.0,
#   'density': 0.9978,
#   'pH': 3.39,
#   'sulphates': 0.61,
#   'alcohol': 10.0,
#   'quality': 6.0,
#   'Id': 116.0},
#  {'fixed acidity': 7.3,
#   'volatile acidity': 1.07,
#   'citric acid': 0.09,
#   'residual sugar': 1.7,
#   'chlorides': 0.17800000000000002,
#   'free sulfur dioxide': 10.0,
#   'total sulfur dioxide': 89.0,
#   'density': 0.9962,
#   'pH': 3.3,
#   'sulphates': 0.57,
#   'alcohol': 9.0,
#   'quality': 5.0,
#   'Id': 120.0},
#  {'fixed acidity': 8.8,
#   'volatile acidity': 0.55,
#   'citric acid': 0.04,
#   'residual sugar': 2.2,
#   'chlorides': 0.11900000000000001,
#   'free sulfur dioxide': 14.0,
#   'total sulfur dioxide': 56.0,
#   'density': 0.9962,
#   'pH': 3.21,
#   'sulphates': 0.6,
#   'alcohol': 10.9,
#   'quality': 6.0,
#   'Id': 121.0},
#  {'fixed acidity': 7.3,
#   'volatile acidity': 0.695,
#   'citric acid': 0.0,
#   'residual sugar': 2.5,
#   'chlorides': 0.075,
#   'free sulfur dioxide': 3.0,
#   'total sulfur dioxide': 13.0,
#   'density': 0.998,
#   'pH': 3.49,
#   'sulphates': 0.52,
#   'alcohol': 9.2,
#   'quality': 5.0,
#   'Id': 122.0},
#  {'fixed acidity': 7.8,
#   'volatile acidity': 0.5,
#   'citric acid': 0.17,
#   'residual sugar': 1.6,
#   'chlorides': 0.08199999999999999,
#   'free sulfur dioxide': 21.0,
#   'total sulfur dioxide': 102.0,
#   'density': 0.996,
#   'pH': 3.39,
#   'sulphates': 0.48,
#   'alcohol': 9.5,
#   'quality': 5.0,
#   'Id': 124.0},
#  {'fixed acidity': 8.2,
#   'volatile acidity': 1.33,
#   'citric acid': 0.0,
#   'residual sugar': 1.7,
#   'chlorides': 0.081,
#   'free sulfur dioxide': 3.0,
#   'total sulfur dioxide': 12.0,
#   'density': 0.9964,
#   'pH': 3.53,
#   'sulphates': 0.49,
#   'alcohol': 10.9,
#   'quality': 5.0,
#   'Id': 126.0},
#  {'fixed acidity': 8.1,
#   'volatile acidity': 1.33,
#   'citric acid': 0.0,
#   'residual sugar': 1.8,
#   'chlorides': 0.08199999999999999,
#   'free sulfur dioxide': 3.0,
#   'total sulfur dioxide': 12.0,
#   'density': 0.9964,
#   'pH': 3.54,
#   'sulphates': 0.48,
#   'alcohol': 10.9,
#   'quality': 5.0,
#   'Id': 127.0},
#  {'fixed acidity': 8.0,
#   'volatile acidity': 0.59,
#   'citric acid': 0.16,
#   'residual sugar': 1.8,
#   'chlorides': 0.065,
#   'free sulfur dioxide': 3.0,
#   'total sulfur dioxide': 16.0,
#   'density': 0.9962,
#   'pH': 3.42,
#   'sulphates': 0.92,
#   'alcohol': 10.5,
#   'quality': 7.0,
#   'Id': 128.0},
#  {'fixed acidity': 8.0,
#   'volatile acidity': 0.745,
#   'citric acid': 0.56,
#   'residual sugar': 2.0,
#   'chlorides': 0.11800000000000001,
#   'free sulfur dioxide': 30.0,
#   'total sulfur dioxide': 134.0,
#   'density': 0.9968,
#   'pH': 3.24,
#   'sulphates': 0.66,
#   'alcohol': 9.4,
#   'quality': 5.0,
#   'Id': 130.0},
#  {'fixed acidity': 5.6,
#   'volatile acidity': 0.5,
#   'citric acid': 0.09,
#   'residual sugar': 2.3,
#   'chlorides': 0.049,
#   'free sulfur dioxide': 17.0,
#   'total sulfur dioxide': 99.0,
#   'density': 0.9937,
#   'pH': 3.63,
#   'sulphates': 0.63,
#   'alcohol': 13.0,
#   'quality': 5.0,
#   'Id': 131.0},
#  {'fixed acidity': 7.9,
#   'volatile acidity': 1.04,
#   'citric acid': 0.05,
#   'residual sugar': 2.2,
#   'chlorides': 0.084,
#   'free sulfur dioxide': 13.0,
#   'total sulfur dioxide': 29.0,
#   'density': 0.9959,
#   'pH': 3.22,
#   'sulphates': 0.55,
#   'alcohol': 9.9,
#   'quality': 6.0,
#   'Id': 134.0},
#  {'fixed acidity': 8.4,
#   'volatile acidity': 0.745,
#   'citric acid': 0.11,
#   'residual sugar': 1.9,
#   'chlorides': 0.09,
#   'free sulfur dioxide': 16.0,
#   'total sulfur dioxide': 63.0,
#   'density': 0.9965,
#   'pH': 3.19,
#   'sulphates': 0.82,
#   'alcohol': 9.6,
#   'quality': 5.0,
#   'Id': 135.0},
#  {'fixed acidity': 7.2,
#   'volatile acidity': 0.415,
#   'citric acid': 0.36,
#   'residual sugar': 2.0,
#   'chlorides': 0.081,
#   'free sulfur dioxide': 13.0,
#   'total sulfur dioxide': 45.0,
#   'density': 0.9972,
#   'pH': 3.48,
#   'sulphates': 0.64,
#   'alcohol': 9.2,
#   'quality': 5.0,
#   'Id': 137.0},
#  {'fixed acidity': 8.4,
#   'volatile acidity': 0.745,
#   'citric acid': 0.11,
#   'residual sugar': 1.9,
#   'chlorides': 0.09,
#   'free sulfur dioxide': 16.0,
#   'total sulfur dioxide': 63.0,
#   'density': 0.9965,
#   'pH': 3.19,
#   'sulphates': 0.82,
#   'alcohol': 9.6,
#   'quality': 5.0,
#   'Id': 140.0},
#  {'fixed acidity': 5.2,
#   'volatile acidity': 0.34,
#   'citric acid': 0.0,
#   'residual sugar': 1.8,
#   'chlorides': 0.05,
#   'free sulfur dioxide': 27.0,
#   'total sulfur dioxide': 63.0,
#   'density': 0.9916,
#   'pH': 3.68,
#   'sulphates': 0.79,
#   'alcohol': 14.0,
#   'quality': 6.0,
#   'Id': 142.0},
#  {'fixed acidity': 6.3,
#   'volatile acidity': 0.39,
#   'citric acid': 0.08,
#   'residual sugar': 1.7,
#   'chlorides': 0.066,
#   'free sulfur dioxide': 3.0,
#   'total sulfur dioxide': 20.0,
#   'density': 0.9954,
#   'pH': 3.34,
#   'sulphates': 0.58,
#   'alcohol': 9.4,
#   'quality': 5.0,
#   'Id': 143.0},
#  {'fixed acidity': 5.2,
#   'volatile acidity': 0.34,
#   'citric acid': 0.0,
#   'residual sugar': 1.8,
#   'chlorides': 0.05,
#   'free sulfur dioxide': 27.0,
#   'total sulfur dioxide': 63.0,
#   'density': 0.9916,
#   'pH': 3.68,
#   'sulphates': 0.79,
#   'alcohol': 14.0,
#   'quality': 6.0,
#   'Id': 144.0},
#  {'fixed acidity': 8.1,
#   'volatile acidity': 0.67,
#   'citric acid': 0.55,
#   'residual sugar': 1.8,
#   'chlorides': 0.11699999999999999,
#   'free sulfur dioxide': 32.0,
#   'total sulfur dioxide': 141.0,
#   'density': 0.9968,
#   'pH': 3.17,
#   'sulphates': 0.62,
#   'alcohol': 9.4,
#   'quality': 5.0,
#   'Id': 145.0},
#  {'fixed acidity': 5.8,
#   'volatile acidity': 0.68,
#   'citric acid': 0.02,
#   'residual sugar': 1.8,
#   'chlorides': 0.087,
#   'free sulfur dioxide': 21.0,
#   'total sulfur dioxide': 94.0,
#   'density': 0.9944,
#   'pH': 3.54,
#   'sulphates': 0.52,
#   'alcohol': 10.0,
#   'quality': 5.0,
#   'Id': 146.0},
#  {'fixed acidity': 6.9,
#   'volatile acidity': 0.49,
#   'citric acid': 0.1,
#   'residual sugar': 2.3,
#   'chlorides': 0.07400000000000001,
#   'free sulfur dioxide': 12.0,
#   'total sulfur dioxide': 30.0,
#   'density': 0.9959,
#   'pH': 3.42,
#   'sulphates': 0.58,
#   'alcohol': 10.2,
#   'quality': 6.0,
#   'Id': 148.0},
#  {'fixed acidity': 7.3,
#   'volatile acidity': 0.33,
#   'citric acid': 0.47,
#   'residual sugar': 2.1,
#   'chlorides': 0.077,
#   'free sulfur dioxide': 5.0,
#   'total sulfur dioxide': 11.0,
#   'density': 0.9958,
#   'pH': 3.33,
#   'sulphates': 0.53,
#   'alcohol': 10.3,
#   'quality': 6.0,
#   'Id': 150.0},
#  {'fixed acidity': 9.2,
#   'volatile acidity': 0.52,
#   'citric acid': 1.0,
#   'residual sugar': 3.4,
#   'chlorides': 0.61,
#   'free sulfur dioxide': 32.0,
#   'total sulfur dioxide': 69.0,
#   'density': 0.9996,
#   'pH': 2.74,
#   'sulphates': 2.0,
#   'alcohol': 9.4,
#   'quality': 4.0,
#   'Id': 151.0},
#  {'fixed acidity': 7.5,
#   'volatile acidity': 0.6,
#   'citric acid': 0.03,
#   'residual sugar': 1.8,
#   'chlorides': 0.095,
#   'free sulfur dioxide': 25.0,
#   'total sulfur dioxide': 99.0,
#   'density': 0.995,
#   'pH': 3.35,
#   'sulphates': 0.54,
#   'alcohol': 10.1,
#   'quality': 5.0,
#   'Id': 152.0},
#  {'fixed acidity': 7.5,
#   'volatile acidity': 0.6,
#   'citric acid': 0.03,
#   'residual sugar': 1.8,
#   'chlorides': 0.095,
#   'free sulfur dioxide': 25.0,
#   'total sulfur dioxide': 99.0,
#   'density': 0.995,
#   'pH': 3.35,
#   'sulphates': 0.54,
#   'alcohol': 10.1,
#   'quality': 5.0,
#   'Id': 153.0},
#  {'fixed acidity': 7.1,
#   'volatile acidity': 0.43,
#   'citric acid': 0.42,
#   'residual sugar': 5.5,
#   'chlorides': 0.071,
#   'free sulfur dioxide': 28.0,
#   'total sulfur dioxide': 128.0,
#   'density': 0.9973,
#   'pH': 3.42,
#   'sulphates': 0.71,
#   'alcohol': 10.5,
#   'quality': 5.0,
#   'Id': 155.0},
#  {'fixed acidity': 7.1,
#   'volatile acidity': 0.43,
#   'citric acid': 0.42,
#   'residual sugar': 5.5,
#   'chlorides': 0.07,
#   'free sulfur dioxide': 29.0,
#   'total sulfur dioxide': 129.0,
#   'density': 0.9973,
#   'pH': 3.42,
#   'sulphates': 0.72,
#   'alcohol': 10.5,
#   'quality': 5.0,
#   'Id': 156.0},
#  {'fixed acidity': 7.1,
#   'volatile acidity': 0.43,
#   'citric acid': 0.42,
#   'residual sugar': 5.5,
#   'chlorides': 0.071,
#   'free sulfur dioxide': 28.0,
#   'total sulfur dioxide': 128.0,
#   'density': 0.9973,
#   'pH': 3.42,
#   'sulphates': 0.71,
#   'alcohol': 10.5,
#   'quality': 5.0,
#   'Id': 157.0},
#  {'fixed acidity': 7.1,
#   'volatile acidity': 0.68,
#   'citric acid': 0.0,
#   'residual sugar': 2.2,
#   'chlorides': 0.073,
#   'free sulfur dioxide': 12.0,
#   'total sulfur dioxide': 22.0,
#   'density': 0.9969,
#   'pH': 3.48,
#   'sulphates': 0.5,
#   'alcohol': 9.3,
#   'quality': 5.0,
#   'Id': 158.0},
#  {'fixed acidity': 6.8,
#   'volatile acidity': 0.6,
#   'citric acid': 0.18,
#   'residual sugar': 1.9,
#   'chlorides': 0.079,
#   'free sulfur dioxide': 18.0,
#   'total sulfur dioxide': 86.0,
#   'density': 0.9968,
#   'pH': 3.59,
#   'sulphates': 0.57,
#   'alcohol': 9.3,
#   'quality': 6.0,
#   'Id': 159.0},
#  {'fixed acidity': 7.6,
#   'volatile acidity': 0.95,
#   'citric acid': 0.03,
#   'residual sugar': 2.0,
#   'chlorides': 0.09,
#   'free sulfur dioxide': 7.0,
#   'total sulfur dioxide': 20.0,
#   'density': 0.9959,
#   'pH': 3.2,
#   'sulphates': 0.56,
#   'alcohol': 9.6,
#   'quality': 5.0,
#   'Id': 160.0},
#  {'fixed acidity': 7.6,
#   'volatile acidity': 0.68,
#   'citric acid': 0.02,
#   'residual sugar': 1.3,
#   'chlorides': 0.07200000000000001,
#   'free sulfur dioxide': 9.0,
#   'total sulfur dioxide': 20.0,
#   'density': 0.9965,
#   'pH': 3.17,
#   'sulphates': 1.08,
#   'alcohol': 9.2,
#   'quality': 4.0,
#   'Id': 161.0},
#  {'fixed acidity': 7.8,
#   'volatile acidity': 0.53,
#   'citric acid': 0.04,
#   'residual sugar': 1.7,
#   'chlorides': 0.076,
#   'free sulfur dioxide': 17.0,
#   'total sulfur dioxide': 31.0,
#   'density': 0.9964,
#   'pH': 3.33,
#   'sulphates': 0.56,
#   'alcohol': 10.0,
#   'quality': 6.0,
#   'Id': 162.0},
#  {'fixed acidity': 7.4,
#   'volatile acidity': 0.6,
#   'citric acid': 0.26,
#   'residual sugar': 7.3,
#   'chlorides': 0.07,
#   'free sulfur dioxide': 36.0,
#   'total sulfur dioxide': 121.0,
#   'density': 0.9982,
#   'pH': 3.37,
#   'sulphates': 0.49,
#   'alcohol': 9.4,
#   'quality': 5.0,
#   'Id': 163.0},
#  {'fixed acidity': 7.3,
#   'volatile acidity': 0.59,
#   'citric acid': 0.26,
#   'residual sugar': 7.2,
#   'chlorides': 0.07,
#   'free sulfur dioxide': 35.0,
#   'total sulfur dioxide': 121.0,
#   'density': 0.9981,
#   'pH': 3.37,
#   'sulphates': 0.49,
#   'alcohol': 9.4,
#   'quality': 5.0,
#   'Id': 164.0},
#  {'fixed acidity': 7.8,
#   'volatile acidity': 0.63,
#   'citric acid': 0.48,
#   'residual sugar': 1.7,
#   'chlorides': 0.1,
#   'free sulfur dioxide': 14.0,
#   'total sulfur dioxide': 96.0,
#   'density': 0.9961,
#   'pH': 3.19,
#   'sulphates': 0.62,
#   'alcohol': 9.5,
#   'quality': 5.0,
#   'Id': 165.0},
#  {'fixed acidity': 6.8,
#   'volatile acidity': 0.64,
#   'citric acid': 0.1,
#   'residual sugar': 2.1,
#   'chlorides': 0.085,
#   'free sulfur dioxide': 18.0,
#   'total sulfur dioxide': 101.0,
#   'density': 0.9956,
#   'pH': 3.34,
#   'sulphates': 0.52,
#   'alcohol': 10.2,
#   'quality': 5.0,
#   'Id': 166.0},
#  {'fixed acidity': 7.3,
#   'volatile acidity': 0.55,
#   'citric acid': 0.03,
#   'residual sugar': 1.6,
#   'chlorides': 0.07200000000000001,
#   'free sulfur dioxide': 17.0,
#   'total sulfur dioxide': 42.0,
#   'density': 0.9956,
#   'pH': 3.37,
#   'sulphates': 0.48,
#   'alcohol': 9.0,
#   'quality': 4.0,
#   'Id': 167.0},
#  {'fixed acidity': 6.8,
#   'volatile acidity': 0.63,
#   'citric acid': 0.07,
#   'residual sugar': 2.1,
#   'chlorides': 0.08900000000000001,
#   'free sulfur dioxide': 11.0,
#   'total sulfur dioxide': 44.0,
#   'density': 0.9953,
#   'pH': 3.47,
#   'sulphates': 0.55,
#   'alcohol': 10.4,
#   'quality': 6.0,
#   'Id': 168.0},
#  {'fixed acidity': 7.9,
#   'volatile acidity': 0.885,
#   'citric acid': 0.03,
#   'residual sugar': 1.8,
#   'chlorides': 0.057999999999999996,
#   'free sulfur dioxide': 4.0,
#   'total sulfur dioxide': 8.0,
#   'density': 0.9972,
#   'pH': 3.36,
#   'sulphates': 0.33,
#   'alcohol': 9.1,
#   'quality': 4.0,
#   'Id': 170.0},
#  {'fixed acidity': 8.0,
#   'volatile acidity': 0.42,
#   'citric acid': 0.17,
#   'residual sugar': 2.0,
#   'chlorides': 0.073,
#   'free sulfur dioxide': 6.0,
#   'total sulfur dioxide': 18.0,
#   'density': 0.9972,
#   'pH': 3.29,
#   'sulphates': 0.61,
#   'alcohol': 9.2,
#   'quality': 6.0,
#   'Id': 172.0},
#  {'fixed acidity': 7.4,
#   'volatile acidity': 0.62,
#   'citric acid': 0.05,
#   'residual sugar': 1.9,
#   'chlorides': 0.068,
#   'free sulfur dioxide': 24.0,
#   'total sulfur dioxide': 42.0,
#   'density': 0.9961,
#   'pH': 3.42,
#   'sulphates': 0.57,
#   'alcohol': 11.5,
#   'quality': 6.0,
#   'Id': 173.0},
#  {'fixed acidity': 6.9,
#   'volatile acidity': 0.5,
#   'citric acid': 0.04,
#   'residual sugar': 1.5,
#   'chlorides': 0.085,
#   'free sulfur dioxide': 19.0,
#   'total sulfur dioxide': 49.0,
#   'density': 0.9958,
#   'pH': 3.35,
#   'sulphates': 0.78,
#   'alcohol': 9.5,
#   'quality': 5.0,
#   'Id': 175.0},
#  {'fixed acidity': 7.3,
#   'volatile acidity': 0.38,
#   'citric acid': 0.21,
#   'residual sugar': 2.0,
#   'chlorides': 0.08,
#   'free sulfur dioxide': 7.0,
#   'total sulfur dioxide': 35.0,
#   'density': 0.9961,
#   'pH': 3.33,
#   'sulphates': 0.47,
#   'alcohol': 9.5,
#   'quality': 5.0,
#   'Id': 176.0},
#  {'fixed acidity': 7.5,
#   'volatile acidity': 0.52,
#   'citric acid': 0.42,
#   'residual sugar': 2.3,
#   'chlorides': 0.087,
#   'free sulfur dioxide': 8.0,
#   'total sulfur dioxide': 38.0,
#   'density': 0.9972,
#   'pH': 3.58,
#   'sulphates': 0.61,
#   'alcohol': 10.5,
#   'quality': 6.0,
#   'Id': 177.0},
#  {'fixed acidity': 7.0,
#   'volatile acidity': 0.805,
#   'citric acid': 0.0,
#   'residual sugar': 2.5,
#   'chlorides': 0.068,
#   'free sulfur dioxide': 7.0,
#   'total sulfur dioxide': 20.0,
#   'density': 0.9969,
#   'pH': 3.48,
#   'sulphates': 0.56,
#   'alcohol': 9.6,
#   'quality': 5.0,
#   'Id': 178.0},
#  {'fixed acidity': 8.8,
#   'volatile acidity': 0.61,
#   'citric acid': 0.14,
#   'residual sugar': 2.4,
#   'chlorides': 0.067,
#   'free sulfur dioxide': 10.0,
#   'total sulfur dioxide': 42.0,
#   'density': 0.9969,
#   'pH': 3.19,
#   'sulphates': 0.59,
#   'alcohol': 9.5,
#   'quality': 5.0,
#   'Id': 179.0},
#  {'fixed acidity': 8.8,
#   'volatile acidity': 0.61,
#   'citric acid': 0.14,
#   'residual sugar': 2.4,
#   'chlorides': 0.067,
#   'free sulfur dioxide': 10.0,
#   'total sulfur dioxide': 42.0,
#   'density': 0.9969,
#   'pH': 3.19,
#   'sulphates': 0.59,
#   'alcohol': 9.5,
#   'quality': 5.0,
#   'Id': 180.0},
#  {'fixed acidity': 8.9,
#   'volatile acidity': 0.61,
#   'citric acid': 0.49,
#   'residual sugar': 2.0,
#   'chlorides': 0.27,
#   'free sulfur dioxide': 23.0,
#   'total sulfur dioxide': 110.0,
#   'density': 0.9972,
#   'pH': 3.12,
#   'sulphates': 1.02,
#   'alcohol': 9.3,
#   'quality': 5.0,
#   'Id': 181.0},
#  {'fixed acidity': 7.2,
#   'volatile acidity': 0.73,
#   'citric acid': 0.02,
#   'residual sugar': 2.5,
#   'chlorides': 0.076,
#   'free sulfur dioxide': 16.0,
#   'total sulfur dioxide': 42.0,
#   'density': 0.9972,
#   'pH': 3.44,
#   'sulphates': 0.52,
#   'alcohol': 9.3,
#   'quality': 5.0,
#   'Id': 182.0},
#  {'fixed acidity': 6.8,
#   'volatile acidity': 0.61,
#   'citric acid': 0.2,
#   'residual sugar': 1.8,
#   'chlorides': 0.077,
#   'free sulfur dioxide': 11.0,
#   'total sulfur dioxide': 65.0,
#   'density': 0.9971,
#   'pH': 3.54,
#   'sulphates': 0.58,
#   'alcohol': 9.3,
#   'quality': 5.0,
#   'Id': 183.0},
#  {'fixed acidity': 6.7,
#   'volatile acidity': 0.62,
#   'citric acid': 0.21,
#   'residual sugar': 1.9,
#   'chlorides': 0.079,
#   'free sulfur dioxide': 8.0,
#   'total sulfur dioxide': 62.0,
#   'density': 0.997,
#   'pH': 3.52,
#   'sulphates': 0.58,
#   'alcohol': 9.3,
#   'quality': 6.0,
#   'Id': 184.0},
#  {'fixed acidity': 8.9,
#   'volatile acidity': 0.31,
#   'citric acid': 0.57,
#   'residual sugar': 2.0,
#   'chlorides': 0.111,
#   'free sulfur dioxide': 26.0,
#   'total sulfur dioxide': 85.0,
#   'density': 0.9971,
#   'pH': 3.26,
#   'sulphates': 0.53,
#   'alcohol': 9.7,
#   'quality': 5.0,
#   'Id': 185.0},
#  {'fixed acidity': 7.4,
#   'volatile acidity': 0.39,
#   'citric acid': 0.48,
#   'residual sugar': 2.0,
#   'chlorides': 0.08199999999999999,
#   'free sulfur dioxide': 14.0,
#   'total sulfur dioxide': 67.0,
#   'density': 0.9972,
#   'pH': 3.34,
#   'sulphates': 0.55,
#   'alcohol': 9.2,
#   'quality': 5.0,
#   'Id': 186.0},
#  {'fixed acidity': 7.9,
#   'volatile acidity': 0.5,
#   'citric acid': 0.33,
#   'residual sugar': 2.0,
#   'chlorides': 0.084,
#   'free sulfur dioxide': 15.0,
#   'total sulfur dioxide': 143.0,
#   'density': 0.9968,
#   'pH': 3.2,
#   'sulphates': 0.55,
#   'alcohol': 9.5,
#   'quality': 5.0,
#   'Id': 188.0},
#  {'fixed acidity': 8.2,
#   'volatile acidity': 0.5,
#   'citric acid': 0.35,
#   'residual sugar': 2.9,
#   'chlorides': 0.077,
#   'free sulfur dioxide': 21.0,
#   'total sulfur dioxide': 127.0,
#   'density': 0.9976,
#   'pH': 3.23,
#   'sulphates': 0.62,
#   'alcohol': 9.4,
#   'quality': 5.0,
#   'Id': 190.0},
#  {'fixed acidity': 6.4,
#   'volatile acidity': 0.37,
#   'citric acid': 0.25,
#   'residual sugar': 1.9,
#   'chlorides': 0.07400000000000001,
#   'free sulfur dioxide': 21.0,
#   'total sulfur dioxide': 49.0,
#   'density': 0.9974,
#   'pH': 3.57,
#   'sulphates': 0.62,
#   'alcohol': 9.8,
#   'quality': 6.0,
#   'Id': 191.0},
#  {'fixed acidity': 7.6,
#   'volatile acidity': 0.55,
#   'citric acid': 0.21,
#   'residual sugar': 2.2,
#   'chlorides': 0.071,
#   'free sulfur dioxide': 7.0,
#   'total sulfur dioxide': 28.0,
#   'density': 0.9964,
#   'pH': 3.28,
#   'sulphates': 0.55,
#   'alcohol': 9.7,
#   'quality': 5.0,
#   'Id': 193.0},
#  {'fixed acidity': 7.6,
#   'volatile acidity': 0.55,
#   'citric acid': 0.21,
#   'residual sugar': 2.2,
#   'chlorides': 0.071,
#   'free sulfur dioxide': 7.0,
#   'total sulfur dioxide': 28.0,
#   'density': 0.9964,
#   'pH': 3.28,
#   'sulphates': 0.55,
#   'alcohol': 9.7,
#   'quality': 5.0,
#   'Id': 194.0},
#  {'fixed acidity': 7.3,
#   'volatile acidity': 0.58,
#   'citric acid': 0.3,
#   'residual sugar': 2.4,
#   'chlorides': 0.07400000000000001,
#   'free sulfur dioxide': 15.0,
#   'total sulfur dioxide': 55.0,
#   'density': 0.9968,
#   'pH': 3.46,
#   'sulphates': 0.59,
#   'alcohol': 10.2,
#   'quality': 5.0,
#   'Id': 196.0},
#  {'fixed acidity': 11.5,
#   'volatile acidity': 0.3,
#   'citric acid': 0.6,
#   'residual sugar': 2.0,
#   'chlorides': 0.067,
#   'free sulfur dioxide': 12.0,
#   'total sulfur dioxide': 27.0,
#   'density': 0.9981,
#   'pH': 3.11,
#   'sulphates': 0.97,
#   'alcohol': 10.1,
#   'quality': 6.0,
#   'Id': 197.0},
#  {'fixed acidity': 6.9,
#   'volatile acidity': 1.09,
#   'citric acid': 0.06,
#   'residual sugar': 2.1,
#   'chlorides': 0.061,
#   'free sulfur dioxide': 12.0,
#   'total sulfur dioxide': 31.0,
#   'density': 0.9948,
#   'pH': 3.51,
#   'sulphates': 0.43,
#   'alcohol': 11.4,
#   'quality': 4.0,
#   'Id': 199.0},
#  {'fixed acidity': 9.6,
#   'volatile acidity': 0.32,
#   'citric acid': 0.47,
#   'residual sugar': 1.4,
#   'chlorides': 0.055999999999999994,
#   'free sulfur dioxide': 9.0,
#   'total sulfur dioxide': 24.0,
#   'density': 0.99695,
#   'pH': 3.22,
#   'sulphates': 0.82,
#   'alcohol': 10.3,
#   'quality': 7.0,
#   'Id': 200.0},
#  {'fixed acidity': 7.0,
#   'volatile acidity': 0.43,
#   'citric acid': 0.36,
#   'residual sugar': 1.6,
#   'chlorides': 0.08900000000000001,
#   'free sulfur dioxide': 14.0,
#   'total sulfur dioxide': 37.0,
#   'density': 0.99615,
#   'pH': 3.34,
#   'sulphates': 0.56,
#   'alcohol': 9.2,
#   'quality': 6.0,
#   'Id': 204.0},
#  {'fixed acidity': 12.8,
#   'volatile acidity': 0.3,
#   'citric acid': 0.74,
#   'residual sugar': 2.6,
#   'chlorides': 0.095,
#   'free sulfur dioxide': 9.0,
#   'total sulfur dioxide': 28.0,
#   'density': 0.9994,
#   'pH': 3.2,
#   'sulphates': 0.77,
#   'alcohol': 10.8,
#   'quality': 7.0,
#   'Id': 205.0},
#  {'fixed acidity': 12.8,
#   'volatile acidity': 0.3,
#   'citric acid': 0.74,
#   'residual sugar': 2.6,
#   'chlorides': 0.095,
#   'free sulfur dioxide': 9.0,
#   'total sulfur dioxide': 28.0,
#   'density': 0.9994,
#   'pH': 3.2,
#   'sulphates': 0.77,
#   'alcohol': 10.8,
#   'quality': 7.0,
#   'Id': 206.0},
#  {'fixed acidity': 7.8,
#   'volatile acidity': 0.44,
#   'citric acid': 0.28,
#   'residual sugar': 2.7,
#   'chlorides': 0.1,
#   'free sulfur dioxide': 18.0,
#   'total sulfur dioxide': 95.0,
#   'density': 0.9966,
#   'pH': 3.22,
#   'sulphates': 0.67,
#   'alcohol': 9.4,
#   'quality': 5.0,
#   'Id': 208.0},
#  {'fixed acidity': 9.7,
#   'volatile acidity': 0.53,
#   'citric acid': 0.6,
#   'residual sugar': 2.0,
#   'chlorides': 0.039,
#   'free sulfur dioxide': 5.0,
#   'total sulfur dioxide': 19.0,
#   'density': 0.99585,
#   'pH': 3.3,
#   'sulphates': 0.86,
#   'alcohol': 12.4,
#   'quality': 6.0,
#   'Id': 210.0},
#  {'fixed acidity': 8.0,
#   'volatile acidity': 0.725,
#   'citric acid': 0.24,
#   'residual sugar': 2.8,
#   'chlorides': 0.083,
#   'free sulfur dioxide': 10.0,
#   'total sulfur dioxide': 62.0,
#   'density': 0.99685,
#   'pH': 3.35,
#   'sulphates': 0.56,
#   'alcohol': 10.0,
#   'quality': 6.0,
#   'Id': 211.0},
#  {'fixed acidity': 8.2,
#   'volatile acidity': 0.57,
#   'citric acid': 0.26,
#   'residual sugar': 2.2,
#   'chlorides': 0.06,
#   'free sulfur dioxide': 28.0,
#   'total sulfur dioxide': 65.0,
#   'density': 0.9959,
#   'pH': 3.3,
#   'sulphates': 0.43,
#   'alcohol': 10.1,
#   'quality': 5.0,
#   'Id': 213.0},
#  {'fixed acidity': 7.8,
#   'volatile acidity': 0.735,
#   'citric acid': 0.08,
#   'residual sugar': 2.4,
#   'chlorides': 0.092,
#   'free sulfur dioxide': 10.0,
#   'total sulfur dioxide': 41.0,
#   'density': 0.9974,
#   'pH': 3.24,
#   'sulphates': 0.71,
#   'alcohol': 9.8,
#   'quality': 6.0,
#   'Id': 214.0},
#  {'fixed acidity': 7.0,
#   'volatile acidity': 0.49,
#   'citric acid': 0.49,
#   'residual sugar': 5.6,
#   'chlorides': 0.06,
#   'free sulfur dioxide': 26.0,
#   'total sulfur dioxide': 121.0,
#   'density': 0.9974,
#   'pH': 3.34,
#   'sulphates': 0.76,
#   'alcohol': 10.5,
#   'quality': 5.0,
#   'Id': 215.0},
#  {'fixed acidity': 8.7,
#   'volatile acidity': 0.625,
#   'citric acid': 0.16,
#   'residual sugar': 2.0,
#   'chlorides': 0.10099999999999999,
#   'free sulfur dioxide': 13.0,
#   'total sulfur dioxide': 49.0,
#   'density': 0.9962,
#   'pH': 3.14,
#   'sulphates': 0.57,
#   'alcohol': 11.0,
#   'quality': 5.0,
#   'Id': 216.0},
#  {'fixed acidity': 8.1,
#   'volatile acidity': 0.725,
#   'citric acid': 0.22,
#   'residual sugar': 2.2,
#   'chlorides': 0.07200000000000001,
#   'free sulfur dioxide': 11.0,
#   'total sulfur dioxide': 41.0,
#   'density': 0.9967,
#   'pH': 3.36,
#   'sulphates': 0.55,
#   'alcohol': 9.1,
#   'quality': 5.0,
#   'Id': 217.0},
#  {'fixed acidity': 7.5,
#   'volatile acidity': 0.49,
#   'citric acid': 0.19,
#   'residual sugar': 1.9,
#   'chlorides': 0.076,
#   'free sulfur dioxide': 10.0,
#   'total sulfur dioxide': 44.0,
#   'density': 0.9957,
#   'pH': 3.39,
#   'sulphates': 0.54,
#   'alcohol': 9.7,
#   'quality': 5.0,
#   'Id': 218.0},
#  {'fixed acidity': 7.8,
#   'volatile acidity': 0.34,
#   'citric acid': 0.37,
#   'residual sugar': 2.0,
#   'chlorides': 0.08199999999999999,
#   'free sulfur dioxide': 24.0,
#   'total sulfur dioxide': 58.0,
#   'density': 0.9964,
#   'pH': 3.34,
#   'sulphates': 0.59,
#   'alcohol': 9.4,
#   'quality': 6.0,
#   'Id': 220.0},
#  {'fixed acidity': 7.4,
#   'volatile acidity': 0.53,
#   'citric acid': 0.26,
#   'residual sugar': 2.0,
#   'chlorides': 0.10099999999999999,
#   'free sulfur dioxide': 16.0,
#   'total sulfur dioxide': 72.0,
#   'density': 0.9957,
#   'pH': 3.15,
#   'sulphates': 0.57,
#   'alcohol': 9.4,
#   'quality': 5.0,
#   'Id': 221.0},
#  {'fixed acidity': 6.8,
#   'volatile acidity': 0.61,
#   'citric acid': 0.04,
#   'residual sugar': 1.5,
#   'chlorides': 0.057,
#   'free sulfur dioxide': 5.0,
#   'total sulfur dioxide': 10.0,
#   'density': 0.99525,
#   'pH': 3.42,
#   'sulphates': 0.6,
#   'alcohol': 9.5,
#   'quality': 5.0,
#   'Id': 222.0},
#  {'fixed acidity': 8.6,
#   'volatile acidity': 0.645,
#   'citric acid': 0.25,
#   'residual sugar': 2.0,
#   'chlorides': 0.083,
#   'free sulfur dioxide': 8.0,
#   'total sulfur dioxide': 28.0,
#   'density': 0.99815,
#   'pH': 3.28,
#   'sulphates': 0.6,
#   'alcohol': 10.0,
#   'quality': 6.0,
#   'Id': 223.0},
#  {'fixed acidity': 7.7,
#   'volatile acidity': 0.43,
#   'citric acid': 0.25,
#   'residual sugar': 2.6,
#   'chlorides': 0.073,
#   'free sulfur dioxide': 29.0,
#   'total sulfur dioxide': 63.0,
#   'density': 0.99615,
#   'pH': 3.37,
#   'sulphates': 0.58,
#   'alcohol': 10.5,
#   'quality': 6.0,
#   'Id': 225.0},
#  {'fixed acidity': 8.9,
#   'volatile acidity': 0.59,
#   'citric acid': 0.5,
#   'residual sugar': 2.0,
#   'chlorides': 0.337,
#   'free sulfur dioxide': 27.0,
#   'total sulfur dioxide': 81.0,
#   'density': 0.9964,
#   'pH': 3.04,
#   'sulphates': 1.61,
#   'alcohol': 9.5,
#   'quality': 6.0,
#   'Id': 226.0},
#  {'fixed acidity': 5.2,
#   'volatile acidity': 0.48,
#   'citric acid': 0.04,
#   'residual sugar': 1.6,
#   'chlorides': 0.054000000000000006,
# ...
#   'alcohol': 9.6,
#   'quality': 5.0,
#   'Id': 1333.0},
#  {'fixed acidity': 7.2,
#   'volatile acidity': 0.835,
#   'citric acid': 0.0,
#   'residual sugar': 2.0,
#   'chlorides': 0.166,
#   'free sulfur dioxide': 4.0,
#   'total sulfur dioxide': 11.0,
#   'density': 0.99608,
#   'pH': 3.39,
#   'sulphates': 0.52,
#   'alcohol': 10.0,
#   'quality': 5.0,
#   'Id': 1334.0},
#  {'fixed acidity': 6.6,
#   'volatile acidity': 0.58,
#   'citric acid': 0.02,
#   'residual sugar': 2.4,
#   'chlorides': 0.069,
#   'free sulfur dioxide': 19.0,
#   'total sulfur dioxide': 40.0,
#   'density': 0.99387,
#   'pH': 3.38,
#   'sulphates': 0.66,
#   'alcohol': 12.6,
#   'quality': 6.0,
#   'Id': 1335.0},
#  {'fixed acidity': 6.0,
#   'volatile acidity': 0.5,
#   'citric acid': 0.0,
#   'residual sugar': 1.4,
#   'chlorides': 0.057,
#   'free sulfur dioxide': 15.0,
#   'total sulfur dioxide': 26.0,
#   'density': 0.9944799999999999,
#   'pH': 3.36,
#   'sulphates': 0.45,
#   'alcohol': 9.5,
#   'quality': 5.0,
#   'Id': 1336.0},
#  {'fixed acidity': 6.0,
#   'volatile acidity': 0.5,
#   'citric acid': 0.0,
#   'residual sugar': 1.4,
#   'chlorides': 0.057,
#   'free sulfur dioxide': 15.0,
#   'total sulfur dioxide': 26.0,
#   'density': 0.9944799999999999,
#   'pH': 3.36,
#   'sulphates': 0.45,
#   'alcohol': 9.5,
#   'quality': 5.0,
#   'Id': 1337.0},
#  {'fixed acidity': 6.0,
#   'volatile acidity': 0.5,
#   'citric acid': 0.0,
#   'residual sugar': 1.4,
#   'chlorides': 0.057,
#   'free sulfur dioxide': 15.0,
#   'total sulfur dioxide': 26.0,
#   'density': 0.9944799999999999,
#   'pH': 3.36,
#   'sulphates': 0.45,
#   'alcohol': 9.5,
#   'quality': 5.0,
#   'Id': 1338.0},
#  {'fixed acidity': 7.5,
#   'volatile acidity': 0.51,
#   'citric acid': 0.02,
#   'residual sugar': 1.7,
#   'chlorides': 0.084,
#   'free sulfur dioxide': 13.0,
#   'total sulfur dioxide': 31.0,
#   'density': 0.9953799999999999,
#   'pH': 3.36,
#   'sulphates': 0.54,
#   'alcohol': 10.5,
#   'quality': 6.0,
#   'Id': 1339.0},
#  {'fixed acidity': 7.5,
#   'volatile acidity': 0.51,
#   'citric acid': 0.02,
#   'residual sugar': 1.7,
#   'chlorides': 0.084,
#   'free sulfur dioxide': 13.0,
#   'total sulfur dioxide': 31.0,
#   'density': 0.9953799999999999,
#   'pH': 3.36,
#   'sulphates': 0.54,
#   'alcohol': 10.5,
#   'quality': 6.0,
#   'Id': 1340.0},
#  {'fixed acidity': 7.5,
#   'volatile acidity': 0.51,
#   'citric acid': 0.02,
#   'residual sugar': 1.7,
#   'chlorides': 0.084,
#   'free sulfur dioxide': 13.0,
#   'total sulfur dioxide': 31.0,
#   'density': 0.9953799999999999,
#   'pH': 3.36,
#   'sulphates': 0.54,
#   'alcohol': 10.5,
#   'quality': 6.0,
#   'Id': 1341.0},
#  {'fixed acidity': 7.5,
#   'volatile acidity': 0.51,
#   'citric acid': 0.02,
#   'residual sugar': 1.7,
#   'chlorides': 0.084,
#   'free sulfur dioxide': 13.0,
#   'total sulfur dioxide': 31.0,
#   'density': 0.9953799999999999,
#   'pH': 3.36,
#   'sulphates': 0.54,
#   'alcohol': 10.5,
#   'quality': 6.0,
#   'Id': 1343.0},
#  {'fixed acidity': 11.5,
#   'volatile acidity': 0.42,
#   'citric acid': 0.48,
#   'residual sugar': 2.6,
#   'chlorides': 0.077,
#   'free sulfur dioxide': 8.0,
#   'total sulfur dioxide': 20.0,
#   'density': 0.9985200000000001,
#   'pH': 3.09,
#   'sulphates': 0.53,
#   'alcohol': 11.0,
#   'quality': 5.0,
#   'Id': 1344.0},
#  {'fixed acidity': 8.2,
#   'volatile acidity': 0.44,
#   'citric acid': 0.24,
#   'residual sugar': 2.3,
#   'chlorides': 0.063,
#   'free sulfur dioxide': 10.0,
#   'total sulfur dioxide': 28.0,
#   'density': 0.99613,
#   'pH': 3.25,
#   'sulphates': 0.53,
#   'alcohol': 10.2,
#   'quality': 6.0,
#   'Id': 1345.0},
#  {'fixed acidity': 6.1,
#   'volatile acidity': 0.59,
#   'citric acid': 0.01,
#   'residual sugar': 2.1,
#   'chlorides': 0.055999999999999994,
#   'free sulfur dioxide': 5.0,
#   'total sulfur dioxide': 13.0,
#   'density': 0.99472,
#   'pH': 3.52,
#   'sulphates': 0.56,
#   'alcohol': 11.4,
#   'quality': 5.0,
#   'Id': 1346.0},
#  {'fixed acidity': 7.2,
#   'volatile acidity': 0.655,
#   'citric acid': 0.03,
#   'residual sugar': 1.8,
#   'chlorides': 0.078,
#   'free sulfur dioxide': 7.0,
#   'total sulfur dioxide': 12.0,
#   'density': 0.99587,
#   'pH': 3.34,
#   'sulphates': 0.39,
#   'alcohol': 9.5,
#   'quality': 5.0,
#   'Id': 1347.0},
#  {'fixed acidity': 7.2,
#   'volatile acidity': 0.62,
#   'citric acid': 0.01,
#   'residual sugar': 2.3,
#   'chlorides': 0.065,
#   'free sulfur dioxide': 8.0,
#   'total sulfur dioxide': 46.0,
#   'density': 0.9933200000000001,
#   'pH': 3.32,
#   'sulphates': 0.51,
#   'alcohol': 11.8,
#   'quality': 6.0,
#   'Id': 1351.0},
#  {'fixed acidity': 7.6,
#   'volatile acidity': 0.645,
#   'citric acid': 0.03,
#   'residual sugar': 1.9,
#   'chlorides': 0.086,
#   'free sulfur dioxide': 14.0,
#   'total sulfur dioxide': 57.0,
#   'density': 0.9969,
#   'pH': 3.37,
#   'sulphates': 0.46,
#   'alcohol': 10.3,
#   'quality': 5.0,
#   'Id': 1353.0},
#  {'fixed acidity': 6.1,
#   'volatile acidity': 0.32,
#   'citric acid': 0.25,
#   'residual sugar': 1.8,
#   'chlorides': 0.086,
#   'free sulfur dioxide': 5.0,
#   'total sulfur dioxide': 32.0,
#   'density': 0.99464,
#   'pH': 3.36,
#   'sulphates': 0.44,
#   'alcohol': 10.1,
#   'quality': 5.0,
#   'Id': 1355.0},
#  {'fixed acidity': 6.1,
#   'volatile acidity': 0.34,
#   'citric acid': 0.25,
#   'residual sugar': 1.8,
#   'chlorides': 0.084,
#   'free sulfur dioxide': 4.0,
#   'total sulfur dioxide': 28.0,
#   'density': 0.99464,
#   'pH': 3.36,
#   'sulphates': 0.44,
#   'alcohol': 10.1,
#   'quality': 5.0,
#   'Id': 1356.0},
#  {'fixed acidity': 7.3,
#   'volatile acidity': 0.43,
#   'citric acid': 0.24,
#   'residual sugar': 2.5,
#   'chlorides': 0.078,
#   'free sulfur dioxide': 27.0,
#   'total sulfur dioxide': 67.0,
#   'density': 0.9964799999999999,
#   'pH': 3.6,
#   'sulphates': 0.59,
#   'alcohol': 11.1,
#   'quality': 6.0,
#   'Id': 1357.0},
#  {'fixed acidity': 7.4,
#   'volatile acidity': 0.64,
#   'citric acid': 0.17,
#   'residual sugar': 5.4,
#   'chlorides': 0.168,
#   'free sulfur dioxide': 52.0,
#   'total sulfur dioxide': 98.0,
#   'density': 0.99736,
#   'pH': 3.28,
#   'sulphates': 0.5,
#   'alcohol': 9.5,
#   'quality': 5.0,
#   'Id': 1358.0},
#  {'fixed acidity': 11.6,
#   'volatile acidity': 0.475,
#   'citric acid': 0.4,
#   'residual sugar': 1.4,
#   'chlorides': 0.091,
#   'free sulfur dioxide': 6.0,
#   'total sulfur dioxide': 28.0,
#   'density': 0.9970399999999999,
#   'pH': 3.07,
#   'sulphates': 0.65,
#   'alcohol': 10.0333333333333,
#   'quality': 6.0,
#   'Id': 1359.0},
#  {'fixed acidity': 8.3,
#   'volatile acidity': 0.85,
#   'citric acid': 0.14,
#   'residual sugar': 2.5,
#   'chlorides': 0.09300000000000001,
#   'free sulfur dioxide': 13.0,
#   'total sulfur dioxide': 54.0,
#   'density': 0.99724,
#   'pH': 3.36,
#   'sulphates': 0.54,
#   'alcohol': 10.1,
#   'quality': 5.0,
#   'Id': 1361.0},
#  {'fixed acidity': 11.6,
#   'volatile acidity': 0.475,
#   'citric acid': 0.4,
#   'residual sugar': 1.4,
#   'chlorides': 0.091,
#   'free sulfur dioxide': 6.0,
#   'total sulfur dioxide': 28.0,
#   'density': 0.9970399999999999,
#   'pH': 3.07,
#   'sulphates': 0.65,
#   'alcohol': 10.0333333333333,
#   'quality': 6.0,
#   'Id': 1362.0},
#  {'fixed acidity': 7.2,
#   'volatile acidity': 0.605,
#   'citric acid': 0.02,
#   'residual sugar': 1.9,
#   'chlorides': 0.096,
#   'free sulfur dioxide': 10.0,
#   'total sulfur dioxide': 31.0,
#   'density': 0.995,
#   'pH': 3.46,
#   'sulphates': 0.53,
#   'alcohol': 11.8,
#   'quality': 6.0,
#   'Id': 1364.0},
#  {'fixed acidity': 7.3,
#   'volatile acidity': 0.74,
#   'citric acid': 0.08,
#   'residual sugar': 1.7,
#   'chlorides': 0.094,
#   'free sulfur dioxide': 10.0,
#   'total sulfur dioxide': 45.0,
#   'density': 0.9957600000000001,
#   'pH': 3.24,
#   'sulphates': 0.5,
#   'alcohol': 9.8,
#   'quality': 5.0,
#   'Id': 1366.0},
#  {'fixed acidity': 6.9,
#   'volatile acidity': 0.54,
#   'citric acid': 0.3,
#   'residual sugar': 2.2,
#   'chlorides': 0.08800000000000001,
#   'free sulfur dioxide': 9.0,
#   'total sulfur dioxide': 105.0,
#   'density': 0.99725,
#   'pH': 3.25,
#   'sulphates': 1.18,
#   'alcohol': 10.5,
#   'quality': 6.0,
#   'Id': 1367.0},
#  {'fixed acidity': 8.0,
#   'volatile acidity': 0.77,
#   'citric acid': 0.32,
#   'residual sugar': 2.1,
#   'chlorides': 0.079,
#   'free sulfur dioxide': 16.0,
#   'total sulfur dioxide': 74.0,
#   'density': 0.99656,
#   'pH': 3.27,
#   'sulphates': 0.5,
#   'alcohol': 9.8,
#   'quality': 6.0,
#   'Id': 1368.0},
#  {'fixed acidity': 8.7,
#   'volatile acidity': 0.78,
#   'citric acid': 0.51,
#   'residual sugar': 1.7,
#   'chlorides': 0.415,
#   'free sulfur dioxide': 12.0,
#   'total sulfur dioxide': 66.0,
#   'density': 0.99623,
#   'pH': 3.0,
#   'sulphates': 1.17,
#   'alcohol': 9.2,
#   'quality': 5.0,
#   'Id': 1370.0},
#  {'fixed acidity': 7.5,
#   'volatile acidity': 0.58,
#   'citric acid': 0.56,
#   'residual sugar': 3.1,
#   'chlorides': 0.153,
#   'free sulfur dioxide': 5.0,
#   'total sulfur dioxide': 14.0,
#   'density': 0.9947600000000001,
#   'pH': 3.21,
#   'sulphates': 1.03,
#   'alcohol': 11.6,
#   'quality': 6.0,
#   'Id': 1371.0},
#  {'fixed acidity': 8.7,
#   'volatile acidity': 0.78,
#   'citric acid': 0.51,
#   'residual sugar': 1.7,
#   'chlorides': 0.415,
#   'free sulfur dioxide': 12.0,
#   'total sulfur dioxide': 66.0,
#   'density': 0.99623,
#   'pH': 3.0,
#   'sulphates': 1.17,
#   'alcohol': 9.2,
#   'quality': 5.0,
#   'Id': 1372.0},
#  {'fixed acidity': 8.2,
#   'volatile acidity': 0.885,
#   'citric acid': 0.2,
#   'residual sugar': 1.4,
#   'chlorides': 0.086,
#   'free sulfur dioxide': 7.0,
#   'total sulfur dioxide': 31.0,
#   'density': 0.9946,
#   'pH': 3.11,
#   'sulphates': 0.46,
#   'alcohol': 10.0,
#   'quality': 5.0,
#   'Id': 1376.0},
#  {'fixed acidity': 7.2,
#   'volatile acidity': 0.45,
#   'citric acid': 0.15,
#   'residual sugar': 2.0,
#   'chlorides': 0.078,
#   'free sulfur dioxide': 10.0,
#   'total sulfur dioxide': 28.0,
#   'density': 0.9960899999999999,
#   'pH': 3.29,
#   'sulphates': 0.51,
#   'alcohol': 9.9,
#   'quality': 6.0,
#   'Id': 1378.0},
#  {'fixed acidity': 7.5,
#   'volatile acidity': 0.57,
#   'citric acid': 0.02,
#   'residual sugar': 2.6,
#   'chlorides': 0.077,
#   'free sulfur dioxide': 11.0,
#   'total sulfur dioxide': 35.0,
#   'density': 0.9955700000000001,
#   'pH': 3.36,
#   'sulphates': 0.62,
#   'alcohol': 10.8,
#   'quality': 6.0,
#   'Id': 1379.0},
#  {'fixed acidity': 7.5,
#   'volatile acidity': 0.57,
#   'citric acid': 0.02,
#   'residual sugar': 2.6,
#   'chlorides': 0.077,
#   'free sulfur dioxide': 11.0,
#   'total sulfur dioxide': 35.0,
#   'density': 0.9955700000000001,
#   'pH': 3.36,
#   'sulphates': 0.62,
#   'alcohol': 10.8,
#   'quality': 6.0,
#   'Id': 1380.0},
#  {'fixed acidity': 8.0,
#   'volatile acidity': 0.6,
#   'citric acid': 0.22,
#   'residual sugar': 2.1,
#   'chlorides': 0.08,
#   'free sulfur dioxide': 25.0,
#   'total sulfur dioxide': 105.0,
#   'density': 0.99613,
#   'pH': 3.3,
#   'sulphates': 0.49,
#   'alcohol': 9.9,
#   'quality': 5.0,
#   'Id': 1382.0},
#  {'fixed acidity': 8.0,
#   'volatile acidity': 0.6,
#   'citric acid': 0.22,
#   'residual sugar': 2.1,
#   'chlorides': 0.08,
#   'free sulfur dioxide': 25.0,
#   'total sulfur dioxide': 105.0,
#   'density': 0.99613,
#   'pH': 3.3,
#   'sulphates': 0.49,
#   'alcohol': 9.9,
#   'quality': 5.0,
#   'Id': 1383.0},
#  {'fixed acidity': 7.1,
#   'volatile acidity': 0.755,
#   'citric acid': 0.15,
#   'residual sugar': 1.8,
#   'chlorides': 0.107,
#   'free sulfur dioxide': 20.0,
#   'total sulfur dioxide': 84.0,
#   'density': 0.99593,
#   'pH': 3.19,
#   'sulphates': 0.5,
#   'alcohol': 9.5,
#   'quality': 5.0,
#   'Id': 1384.0},
#  {'fixed acidity': 8.0,
#   'volatile acidity': 0.81,
#   'citric acid': 0.25,
#   'residual sugar': 3.4,
#   'chlorides': 0.076,
#   'free sulfur dioxide': 34.0,
#   'total sulfur dioxide': 85.0,
#   'density': 0.9966799999999999,
#   'pH': 3.19,
#   'sulphates': 0.42,
#   'alcohol': 9.2,
#   'quality': 5.0,
#   'Id': 1385.0},
#  {'fixed acidity': 7.4,
#   'volatile acidity': 0.64,
#   'citric acid': 0.07,
#   'residual sugar': 1.8,
#   'chlorides': 0.1,
#   'free sulfur dioxide': 8.0,
#   'total sulfur dioxide': 23.0,
#   'density': 0.9961,
#   'pH': 3.3,
#   'sulphates': 0.58,
#   'alcohol': 9.6,
#   'quality': 5.0,
#   'Id': 1386.0},
#  {'fixed acidity': 6.6,
#   'volatile acidity': 0.64,
#   'citric acid': 0.31,
#   'residual sugar': 6.1,
#   'chlorides': 0.083,
#   'free sulfur dioxide': 7.0,
#   'total sulfur dioxide': 49.0,
#   'density': 0.99718,
#   'pH': 3.35,
#   'sulphates': 0.68,
#   'alcohol': 10.3,
#   'quality': 5.0,
#   'Id': 1388.0},
#  {'fixed acidity': 6.0,
#   'volatile acidity': 0.49,
#   'citric acid': 0.0,
#   'residual sugar': 2.3,
#   'chlorides': 0.068,
#   'free sulfur dioxide': 15.0,
#   'total sulfur dioxide': 33.0,
#   'density': 0.99292,
#   'pH': 3.58,
#   'sulphates': 0.59,
#   'alcohol': 12.5,
#   'quality': 6.0,
#   'Id': 1390.0},
#  {'fixed acidity': 8.0,
#   'volatile acidity': 0.64,
#   'citric acid': 0.22,
#   'residual sugar': 2.4,
#   'chlorides': 0.094,
#   'free sulfur dioxide': 5.0,
#   'total sulfur dioxide': 33.0,
#   'density': 0.9961200000000001,
#   'pH': 3.37,
#   'sulphates': 0.58,
#   'alcohol': 11.0,
#   'quality': 5.0,
#   'Id': 1391.0},
#  {'fixed acidity': 7.1,
#   'volatile acidity': 0.62,
#   'citric acid': 0.06,
#   'residual sugar': 1.3,
#   'chlorides': 0.07,
#   'free sulfur dioxide': 5.0,
#   'total sulfur dioxide': 12.0,
#   'density': 0.9942,
#   'pH': 3.17,
#   'sulphates': 0.48,
#   'alcohol': 9.8,
#   'quality': 5.0,
#   'Id': 1392.0},
#  {'fixed acidity': 8.0,
#   'volatile acidity': 0.52,
#   'citric acid': 0.25,
#   'residual sugar': 2.0,
#   'chlorides': 0.078,
#   'free sulfur dioxide': 19.0,
#   'total sulfur dioxide': 59.0,
#   'density': 0.9961200000000001,
#   'pH': 3.3,
#   'sulphates': 0.48,
#   'alcohol': 10.2,
#   'quality': 5.0,
#   'Id': 1393.0},
#  {'fixed acidity': 8.6,
#   'volatile acidity': 0.685,
#   'citric acid': 0.1,
#   'residual sugar': 1.6,
#   'chlorides': 0.092,
#   'free sulfur dioxide': 3.0,
#   'total sulfur dioxide': 12.0,
#   'density': 0.99745,
#   'pH': 3.31,
#   'sulphates': 0.65,
#   'alcohol': 9.55,
#   'quality': 6.0,
#   'Id': 1395.0},
#  {'fixed acidity': 8.7,
#   'volatile acidity': 0.675,
#   'citric acid': 0.1,
#   'residual sugar': 1.6,
#   'chlorides': 0.09,
#   'free sulfur dioxide': 4.0,
#   'total sulfur dioxide': 11.0,
#   'density': 0.99745,
#   'pH': 3.31,
#   'sulphates': 0.65,
#   'alcohol': 9.55,
#   'quality': 5.0,
#   'Id': 1396.0},
#  {'fixed acidity': 7.3,
#   'volatile acidity': 0.59,
#   'citric acid': 0.26,
#   'residual sugar': 2.0,
#   'chlorides': 0.08,
#   'free sulfur dioxide': 17.0,
#   'total sulfur dioxide': 104.0,
#   'density': 0.99584,
#   'pH': 3.28,
#   'sulphates': 0.52,
#   'alcohol': 9.9,
#   'quality': 5.0,
#   'Id': 1397.0},
#  {'fixed acidity': 7.2,
#   'volatile acidity': 0.67,
#   'citric acid': 0.0,
#   'residual sugar': 2.2,
#   'chlorides': 0.068,
#   'free sulfur dioxide': 10.0,
#   'total sulfur dioxide': 24.0,
#   'density': 0.9956,
#   'pH': 3.42,
#   'sulphates': 0.72,
#   'alcohol': 11.1,
#   'quality': 6.0,
#   'Id': 1399.0},
#  {'fixed acidity': 7.9,
#   'volatile acidity': 0.69,
#   'citric acid': 0.21,
#   'residual sugar': 2.1,
#   'chlorides': 0.08,
#   'free sulfur dioxide': 33.0,
#   'total sulfur dioxide': 141.0,
#   'density': 0.9962,
#   'pH': 3.25,
#   'sulphates': 0.51,
#   'alcohol': 9.9,
#   'quality': 5.0,
#   'Id': 1400.0},
#  {'fixed acidity': 7.6,
#   'volatile acidity': 0.3,
#   'citric acid': 0.42,
#   'residual sugar': 2.0,
#   'chlorides': 0.052000000000000005,
#   'free sulfur dioxide': 6.0,
#   'total sulfur dioxide': 24.0,
#   'density': 0.9963,
#   'pH': 3.44,
#   'sulphates': 0.82,
#   'alcohol': 11.9,
#   'quality': 6.0,
#   'Id': 1402.0},
#  {'fixed acidity': 7.2,
#   'volatile acidity': 0.33,
#   'citric acid': 0.33,
#   'residual sugar': 1.7,
#   'chlorides': 0.061,
#   'free sulfur dioxide': 3.0,
#   'total sulfur dioxide': 13.0,
#   'density': 0.996,
#   'pH': 3.23,
#   'sulphates': 1.1,
#   'alcohol': 10.0,
#   'quality': 8.0,
#   'Id': 1403.0},
#  {'fixed acidity': 8.0,
#   'volatile acidity': 0.5,
#   'citric acid': 0.39,
#   'residual sugar': 2.6,
#   'chlorides': 0.08199999999999999,
#   'free sulfur dioxide': 12.0,
#   'total sulfur dioxide': 46.0,
#   'density': 0.9985,
#   'pH': 3.43,
#   'sulphates': 0.62,
#   'alcohol': 10.7,
#   'quality': 6.0,
#   'Id': 1404.0},
#  {'fixed acidity': 8.2,
#   'volatile acidity': 0.24,
#   'citric acid': 0.34,
#   'residual sugar': 5.1,
#   'chlorides': 0.062,
#   'free sulfur dioxide': 8.0,
#   'total sulfur dioxide': 22.0,
#   'density': 0.9974,
#   'pH': 3.22,
#   'sulphates': 0.94,
#   'alcohol': 10.9,
#   'quality': 6.0,
#   'Id': 1406.0},
#  {'fixed acidity': 6.0,
#   'volatile acidity': 0.51,
#   'citric acid': 0.0,
#   'residual sugar': 2.1,
#   'chlorides': 0.064,
#   'free sulfur dioxide': 40.0,
#   'total sulfur dioxide': 54.0,
#   'density': 0.995,
#   'pH': 3.54,
#   'sulphates': 0.93,
#   'alcohol': 10.7,
#   'quality': 6.0,
#   'Id': 1407.0},
#  ...]

# %%
#QUALITY ATTRIBUTE VALUES :
# 0(bad) if x<=6 and 1(good) if x>6.
q='quality'
for r in wine:
    if r[q] > 6:
        r[q] = 1
    else:
        r[q] = 0

# %%
wine[0].keys()
# Out:
# dict_keys(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol', 'quality', 'Id'])

# %%
#MIN MAX SCALING TECHNIQUE :

col =[]
for i in wine[0].keys():
   # print(i)
    if i!= q:       #Excluding 'quality' column from min max scaling
        col+=[i]
        
col

#creating two rows to store min and max values of each column
mins = {c: float('inf') for c in col}
maxs = {c: float('-inf') for c in col}

for r in wine:
    for c in col:
        if r[c] < mins[c]:
            mins[c] = r[c]
        if r[c] > maxs[c]:
            maxs[c] = r[c]

# %%
mins,maxs
# Out:
# ({'fixed acidity': 4.6,
#   'volatile acidity': 0.12,
#   'citric acid': 0.0,
#   'residual sugar': 0.9,
#   'chlorides': 0.012,
#   'free sulfur dioxide': 1.0,
#   'total sulfur dioxide': 6.0,
#   'density': 0.9900700000000001,
#   'pH': 2.74,
#   'sulphates': 0.33,
#   'alcohol': 8.4,
#   'Id': 0.0},
#  {'fixed acidity': 15.9,
#   'volatile acidity': 1.58,
#   'citric acid': 1.0,
#   'residual sugar': 15.5,
#   'chlorides': 0.611,
#   'free sulfur dioxide': 68.0,
#   'total sulfur dioxide': 289.0,
#   'density': 1.00369,
#   'pH': 4.01,
#   'sulphates': 2.0,
#   'alcohol': 14.9,
#   'Id': 1597.0})

# %%
# MIN-MAX SCALING
for r in wine:
    for c in col:
        r[c] = (r[c] - mins[c]) / (maxs[c] - mins[c])  #Normalization formula

# %%
w2= open('wineQT_after_min_max.csv', mode='w', newline='')   #write normalized data to new file
writer = csv.DictWriter(w2, fieldnames=wine[0].keys())
writer.writeheader()
writer.writerows(wine)

# %%
w3=pd.read_csv('wineQT_after_min_max.csv')
w3
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0         -0.385152          0.189904         0.00       -0.056953   0.158338
# 1         -0.382019          0.274348         0.00       -0.053669   0.219654
# 2         -0.382019          0.218052         0.04       -0.055076   0.202931
# 3         -0.355392         -0.007131         0.56       -0.056953   0.155551
# 4         -0.385152          0.189904         0.00       -0.056953   0.158338
# ...             ...               ...          ...             ...        ...
# 1138      -0.393766          0.100769         0.13       -0.055076   0.158338
# 1139      -0.389850          0.152374         0.08       -0.056953   0.136042
# 1140      -0.394549          0.142991         0.08       -0.056483   0.197357
# 1141      -0.396899          0.119535         0.10       -0.055545   0.119320
# 1142      -0.396899          0.164102         0.12       -0.056483   0.155551
#
#       free sulfur dioxide  total sulfur dioxide    density        pH  \
# 0               -0.012698             -0.020852 -31.022194 -1.680079
# 1               -0.009579             -0.020440 -36.412901 -1.872280
# 2               -0.011807             -0.020602 -35.334760 -1.835080
# 3               -0.011361             -0.020527 -29.944052 -1.897080
# 4               -0.012698             -0.020852 -31.022194 -1.680079
# ...                   ...                   ...        ...       ...
# 1138            -0.008688             -0.020777 -42.127051 -1.735879
# 1139            -0.008911             -0.020802 -37.976206 -1.735879
# 1140            -0.008020             -0.020727 -46.655246 -1.717279
# 1141            -0.006460             -0.020640 -45.469290 -1.673879
# 1142            -0.008020             -0.020727 -43.582543 -1.642879
#
#       sulphates   alcohol  quality            Id
# 0     -0.115135 -1.268639        0  0.000000e+00
# 1     -0.072107 -1.259172        0  3.920940e-07
# 2     -0.082864 -1.259172        0  7.841879e-07
# 3     -0.107964 -1.259172        0  1.176282e-06
# 4     -0.115135 -1.268639        0  1.568376e-06
# ...         ...       ...      ...           ...
# 1138  -0.047008 -1.230769        0  6.242136e-04
# 1139  -0.021908 -1.266272        0  6.246057e-04
# 1140  -0.107964 -1.242604        0  6.249978e-04
# 1141  -0.043422 -1.226036        0  6.253899e-04
# 1142  -0.061350 -1.249704        0  6.261741e-04
#
# [1143 rows x 13 columns]

# %% [markdown]
# ## Why we use MIN- MAX SCALING?

# %% [markdown]
# Different features in the dataset wineQT have different units and scales (Ex: Density, pH, Acid Levels and Quality).
#
# Min-max scaling standardizes these features to a uniform scale of range 0 to 1 ensuring that no single feature dominates others due to its larger magnitude.
#
# This makes interpretation easier and relatively simpler making algorithms that rely on distance calculations, like k-means clustering and k-nearest neighbors, perform better.
